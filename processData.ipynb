# %%
from persianNumberNormalizer import PersianNumberNormalizer 
import re,pandas as pd,numpy as np,datetime

# %%
df = pd.read_excel("output/price_of_fertilizers - Copy (10).xlsx"
                   ,sheet_name=None)
df
# Out:
# {'agriplus.ir':                                                    url  \
#  0    https://agriplus.ir/Product/BKP-35038/%da%a9%d...
#  1    https://agriplus.ir/Product/BKP-27426/%da%a9%d...
#  2    https://agriplus.ir/Product/BKP-22917/%da%a9%d...
#  3    https://agriplus.ir/Product/BKP-22916/%da%a9%d...
#  4    https://agriplus.ir/Product/BKP-21436/%da%a9%d...
#  ..                                                 ...
#  233  https://agriplus.ir/Product/BKP-14233/%d9%be%d...
#  234  https://agriplus.ir/Product/BKP-37836/rooty-sg15/
#  235  https://agriplus.ir/Product/BKP-24561/rooting-...
#  236  https://agriplus.ir/Product/BKP-36035/rooty-ho...
#  237  https://agriplus.ir/Product/BKP-37832/rooty-sy...
#
#                                               name          category    price  \
#  0                          کود NPK ۳۰ ۱۰ ۱۰ زیگلر           کود NPK      NaN
#  1                 کود سه بیست لبین (NPK ۲۰ ۲۰ ۲۰)           کود NPK      NaN
#  2    کود NPK تحریک گلدهی ۳۶ ۱۲ ۱۲ بسته بندی خانگی         کود خانگی  1233400
#  3        کود محرک رشد ۲۰ ۲۰ ۲۰ با بسته بندی خانگی         کود خانگی   198000
#  4                       کود NPK ۱۵ ۵ ۳۰ کوالی مکس           کود NPK      NaN
#  ..                                            ...               ...      ...
#  233                    پودر جیبرلین BERELEX ۴۰ SG  هورمون رشد گیاهی      NaN
#  234    هورمون ریشه زایی هلندی روتی SG15 اگری پلاس  هورمون رشد گیاهی      NaN
#  235           هورمون ریشه زایی هندی L30 اگری پلاس  هورمون رشد گیاهی      NaN
#  236    هورمون ریشه‌ زایی هلندی روتی L30 اگری پلاس  هورمون رشد گیاهی      NaN
#  237    هورمون ریشه زایی غلیظ روتی Syrup اگری پلاس  هورمون رشد گیاهی      NaN
#
#       price_per_kg  amount_kg  last_price_update is_available  \
#  0             NaN        NaN                NaN        False
#  1             NaN        NaN                NaN        False
#  2             NaN        NaN                NaN         True
#  3             NaN        NaN                NaN         True
#  4             NaN        NaN                NaN        False
#  ..            ...        ...                ...          ...
#  233           NaN        NaN                NaN        False
#  234           NaN        NaN                NaN        False
#  235           NaN        NaN                NaN        False
#  236           NaN        NaN                NaN        False
#  237           NaN        NaN                NaN        False
#
#                created_at         last_updated  product_menu_url
#  0    2025-07-22 15:50:46  2025-08-12 08:36:14               NaN
#  1    2025-07-22 15:50:50  2025-08-12 08:36:20               NaN
#  2    2025-07-22 15:50:52  2025-08-12 08:52:40               NaN
#  3    2025-07-22 15:50:55  2025-08-12 08:53:18               NaN
#  4    2025-07-22 15:50:58  2025-08-12 08:36:39               NaN
#  ..                   ...                  ...               ...
#  233  2025-07-22 16:34:21  2025-08-12 09:33:25               NaN
#  234  2025-08-12 09:32:35  2025-08-12 09:32:35               NaN
#  235  2025-08-12 09:32:48  2025-08-12 09:32:48               NaN
#  236  2025-08-12 09:32:54  2025-08-12 09:32:54               NaN
#  237  2025-08-12 09:33:06  2025-08-12 09:33:06               NaN
#
#  [238 rows x 11 columns],
#  'torob.com':                                                     url  \
#  0     https://torob.com/p/2b84fb38-5f28-47ed-904d-1a...
#  1     https://torob.com/p/ae8d4083-b06f-4d62-b5f1-38...
#  2     https://torob.com/p/86e88419-cd7b-4fb1-9fb5-72...
#  3     https://torob.com/p/570734d8-40be-4f91-87d7-b5...
#  4     https://torob.com/p/bade8776-56ef-4605-82a5-f5...
#  ...                                                 ...
#  1556  https://torob.com/p/8293600b-2a42-4364-9983-cd...
#  1557  https://torob.com/p/f3151753-ea93-454e-a6e2-ac...
#  1558  https://torob.com/p/1d9f604d-5a93-49af-a6db-a7...
#  1559  https://torob.com/p/ea2cb9c3-71b7-44ab-9a28-78...
#  1560  https://torob.com/p/eeb69058-7863-423e-8bbc-4e...
#
#                                                     name  category   price  \
#  0                  کود جلبک دریایی مایع شوک اصل 5 لیتری       NaN  888000
#  1                              قرص کود ارگانیک 120 عددی       NaN   66000
#  2                       کود شیمیایی اوره گرانول 46 درصد       NaN   70000
#  3                            پودر هیومیک اسید پلنت چویس       NaN  630000
#  4     کود سه بیست 20 20 برند هایپر ایکس گرین - کود ک...       NaN  240000
#  ...                                                 ...       ...     ...
#  1556                      صابون حشره کش جنوبگان 5 لیتری       NaN  365000
#  1557                       کود آلی مایع زرگرین ۲۰ لیتری       NaN  820000
#  1558            کود نیترات کلسیم جنوبگان وزن ۲۵ کیلوگرم       NaN  110000
#  1559        کود گوگرد مایع شوک ۲۰ لیتری ۸۰ درصد ارگانیک       NaN  260000
#  1560           کود پلیت مرغی زرین مهر کیمیا 25 کیلوگرمی       NaN  227500
#
#        price_per_kg  amount_kg  last_price_update  is_available  \
#  0         177600.0        5.0                NaN          True
#  1              NaN        NaN                NaN          True
#  2              NaN        NaN                NaN          True
#  3              NaN        NaN                NaN          True
#  4              NaN        NaN                NaN          True
#  ...            ...        ...                ...           ...
#  1556       73000.0        5.0                NaN          True
#  1557       41000.0       20.0                NaN          True
#  1558        4400.0       25.0                NaN          True
#  1559       13000.0       20.0                NaN          True
#  1560        9100.0       25.0                NaN          True
#
#                 created_at         last_updated  product_menu_url
#  0     2025-07-22 16:45:39  2025-07-27 16:48:28               NaN
#  1     2025-07-22 16:45:40  2025-07-29 15:01:00               NaN
#  2     2025-07-22 16:45:40  2025-07-22 16:45:40               NaN
#  3     2025-07-22 16:45:40  2025-07-22 16:45:40               NaN
#  4     2025-07-22 16:45:40  2025-07-29 15:01:04               NaN
#  ...                   ...                  ...               ...
#  1556  2025-07-29 15:00:59  2025-07-29 15:00:59               NaN
#  1557  2025-07-29 15:02:06  2025-07-29 15:02:06               NaN
#  1558  2025-07-29 15:02:12  2025-07-29 15:02:12               NaN
#  1559  2025-07-29 15:02:19  2025-07-29 15:02:19               NaN
#  1560  2025-07-29 15:03:02  2025-07-29 15:03:02               NaN
#
#  [1561 rows x 11 columns],
#  'digikood.com':                                                   url  \
#  0   https://www.digikood.com/product/%da%a9%d9%84%...
#  1   https://www.digikood.com/product/%d9%81%d8%b3%...
#  2         https://www.digikood.com/product/__trashed/
#  3   https://www.digikood.com/product/%da%a9%d9%88%...
#  4   https://www.digikood.com/product/%d8%a7%d9%88%...
#  ..                                                ...
#  83  https://www.digikood.com/product/%d8%b6%d8%af-...
#  84  https://www.digikood.com/product/%da%a9%d9%88%...
#  85  https://www.digikood.com/product/%d8%a8%d8%a7%...
#  86  https://www.digikood.com/product/%da%a9%d9%85%...
#  87  https://www.digikood.com/product/%da%af%d9%88%...
#
#                             name       category      price  price_per_kg  \
#  0   کلات آهن لایفر ۶٪ اسپانیایی   شیمیایی جامد  1200000.0           NaN
#  1                  فسفات گوگردی   شیمیایی جامد   850000.0       17000.0
#  2                ماکرو 20 20 20   شیمیایی جامد  3500000.0     3500000.0
#  3                کود کامل خانگی   شیمیایی جامد        NaN           NaN
#  4                   اوره گوگردی   شیمیایی جامد   850000.0       34000.0
#  ..                          ...            ...        ...           ...
#  83                  ضد یخ گیاهی  کودهای گوگردی        NaN           NaN
#  84          کود بیولوژیک بیوراس  کود های زیستی  2125000.0       85000.0
#  85   بایوکامپوزیت گوگردی (تیاس)  کودهای گوگردی  3800000.0     1900000.0
#  86            کمپوست آلی سلولزی       ریز مغزی   180000.0       18000.0
#  87                   گوگرد مایع  کودهای گوگردی  1750000.0      350000.0
#
#      amount_kg  last_price_update  is_available           created_at  \
#  0         0.0                NaN          True  2025-07-22 17:05:51
#  1        50.0                NaN          True  2025-07-22 17:05:56
#  2         1.0                NaN          True  2025-07-22 17:06:01
#  3        10.0                NaN          True  2025-07-22 17:06:06
#  4        25.0                NaN          True  2025-07-22 17:06:11
#  ..        ...                ...           ...                  ...
#  83        1.0                NaN          True  2025-07-22 17:19:39
#  84       25.0                NaN          True  2025-07-22 17:20:21
#  85        2.0                NaN          True  2025-07-22 17:20:26
#  86       10.0                NaN          True  2025-07-22 17:20:31
#  87        5.0                NaN          True  2025-07-22 17:24:31
#
#             last_updated  product_menu_url  \
#  0   2025-08-13 03:16:52               NaN
#  1   2025-08-13 03:17:01               NaN
#  2   2025-08-13 03:17:09               NaN
#  3   2025-08-13 03:17:19               NaN
#  4   2025-08-13 03:17:28               NaN
#  ..                  ...               ...
#  83  2025-07-27 17:46:51               NaN
#  84  2025-07-27 17:44:48               NaN
#  85  2025-07-27 17:45:47               NaN
#  86  2025-07-27 17:40:18               NaN
#  87  2025-07-27 17:45:52               NaN
#
#                                                    _pk
#  0   https://www.digikood.com/product/%da%a9%d9%84%...
#  1   https://www.digikood.com/product/%d9%81%d8%b3%...
#  2   https://www.digikood.com/product/__trashed/::م...
#  3   https://www.digikood.com/product/%da%a9%d9%88%...
#  4   https://www.digikood.com/product/%d8%a7%d9%88%...
#  ..                                                ...
#  83  https://www.digikood.com/product/%d8%b6%d8%af-...
#  84  https://www.digikood.com/product/%da%a9%d9%88%...
#  85  https://www.digikood.com/product/%d8%a8%d8%a7%...
#  86  https://www.digikood.com/product/%da%a9%d9%85%...
#  87  https://www.digikood.com/product/%da%af%d9%88%...
#
#  [88 rows x 12 columns],
#  'koodforosh.com':                                      url  \
#  0       https://koodforosh.com/showads/6
#  1    https://koodforosh.com/showads/2194
#  2    https://koodforosh.com/showads/2253
#  3    https://koodforosh.com/showads/2945
#  4    https://koodforosh.com/showads/2930
#  ..                                   ...
#  180  https://koodforosh.com/showads/3444
#  181  https://koodforosh.com/showads/3445
#  182  https://koodforosh.com/showads/3446
#  183  https://koodforosh.com/showads/3447
#  184  https://koodforosh.com/showads/3448
#
#                                                    name    category    price  \
#  0    روش استفاده از کود سولفات امونیوم گرانوله در ش...  کود سولفات  ۱۱۵,۰۰۰
#  1                                  فروش کود سولفات اهن  کود سولفات      NaN
#  2                                  فروش سولفات امونیوم  کود سولفات      NaN
#  3                                  فروش سولفات آمونیوم  کود سولفات      NaN
#  4                                       کود NK 5‐5 آفر    کود پتاس      NaN
#  ..                                                 ...         ...      ...
#  180           آیا کود هوموس برای همه گیاهان مناسب است؟   کود هوموس    ۲,۵۰۰
#  181                   چگونه از کود هوموس استفاده کنیم؟   کود هوموس    ۲,۵۰۰
#  182           کود هوموس چگونه به بهبود خاک کمک می‌کند؟   کود هوموس    ۲,۵۰۰
#  183       آیا کود هوموس باعث افزایش رشد گیاهان می‌شود؟   کود هوموس    ۲,۵۰۰
#  184           کود هوموس چگونه به محیط زیست کمک می‌کند؟   کود هوموس    ۲,۵۰۰
#
#       price_per_kg  amount_kg  last_price_update  is_available  \
#  0             NaN        NaN                NaN           NaN
#  1             NaN        NaN                NaN           NaN
#  2             NaN        NaN                NaN           NaN
#  3             NaN        NaN                NaN           NaN
#  4             NaN        NaN                NaN           NaN
#  ..            ...        ...                ...           ...
#  180           NaN        NaN                NaN           NaN
#  181           NaN        NaN                NaN           NaN
#  182           NaN        NaN                NaN           NaN
#  183           NaN        NaN                NaN           NaN
#  184           NaN        NaN                NaN           NaN
#
#                created_at         last_updated  product_menu_url
#  0    2025-07-22 17:28:23  2025-08-12 08:00:25               NaN
#  1    2025-07-22 17:28:25  2025-08-12 08:00:29               NaN
#  2    2025-07-22 17:28:34  2025-08-12 08:00:38               NaN
#  3    2025-07-22 17:28:38  2025-08-12 08:00:43               NaN
#  4    2025-07-22 17:29:20  2025-08-12 08:01:27               NaN
#  ..                   ...                  ...               ...
#  180  2025-07-22 17:39:06  2025-08-12 08:18:41               NaN
#  181  2025-07-22 17:39:07  2025-08-12 08:18:44               NaN
#  182  2025-07-22 17:39:08  2025-08-12 08:18:48               NaN
#  183  2025-07-22 17:39:10  2025-08-12 08:18:51               NaN
#  184  2025-07-22 17:39:11  2025-08-12 08:18:54               NaN
#
#  [185 rows x 11 columns],
#  'digikoud.com':                                                   url  \
#  0   https://digikoud.com/کود-های-پتاسه/9-نیترات-پت...
#  1   https://digikoud.com/کود-های-پتاسه/8-سولفات-پت...
#  2   https://digikoud.com/کود-های-مرکب/37-مونو-پتاس...
#  3   https://digikoud.com/کود-های-مایع/72-کود-زیستی...
#  4   https://digikoud.com/کود-کامل-ماکرو-/182-ماکرو...
#  ..                                                ...
#  77  https://digikoud.com/کود-مخصوص-گل-و-سبزیجات/16...
#  78  https://digikoud.com/کود-مخصوص-گل-و-سبزیجات/16...
#  79  https://digikoud.com/کود-مخصوص-گل-و-سبزیجات/16...
#  80  https://digikoud.com/کود-مخصوص-گل-و-سبزیجات/17...
#  81  https://digikoud.com/کود-مخصوص-گل-و-سبزیجات/17...
#
#                           name                    category  price  \
#  0               نیترات پتاسیم            کود های مرکب\n37    NaN
#  1   سولفات پتاسیم منیزیم 10/4        کود های ریز مغزی\n17    NaN
#  2           مونو پتاسیم فسفات            کود های مرکب\n37    NaN
#  3        کود زیستی پتابارور-2            کود های مایع\n12    NaN
#  4          ماکرو کامل20/20/20      کود کامل ( ماکرو )\n23    NaN
#  ..                        ...                         ...    ...
#  77       کود گیاهان آپارتمانی  کود مخصوص گل و سبزیجات\n15    NaN
#  78        کود گیاهان باغچه ای  کود مخصوص گل و سبزیجات\n15    NaN
#  79                  کود گلدهی  کود مخصوص گل و سبزیجات\n15    NaN
#  80                     کود رز  کود مخصوص گل و سبزیجات\n15    NaN
#  81       کود رشد مخصوص گیاهان  کود مخصوص گل و سبزیجات\n15    NaN
#
#      price_per_kg  amount_kg  last_price_update  is_available  \
#  0            NaN        NaN                NaN           NaN
#  1            NaN        NaN                NaN           NaN
#  2            NaN        NaN                NaN           NaN
#  3            NaN        NaN                NaN           NaN
#  4            NaN        NaN                NaN           NaN
#  ..           ...        ...                ...           ...
#  77           NaN        NaN                NaN           NaN
#  78           NaN        NaN                NaN           NaN
#  79           NaN        NaN                NaN           NaN
#  80           NaN        NaN                NaN           NaN
#  81           NaN        NaN                NaN           NaN
#
#               created_at         last_updated  product_menu_url
#  0   2025-07-22 17:39:20  2025-08-12 08:27:27               NaN
#  1   2025-07-22 17:39:23  2025-08-12 08:31:08               NaN
#  2   2025-07-22 17:39:27  2025-08-12 08:27:17               NaN
#  3   2025-07-22 17:39:30  2025-08-12 08:23:08               NaN
#  4   2025-07-22 17:39:33  2025-08-12 08:33:11               NaN
#  ..                  ...                  ...               ...
#  77  2025-07-22 17:48:49  2025-08-12 08:34:57               NaN
#  78  2025-07-22 17:48:52  2025-08-12 08:35:02               NaN
#  79  2025-07-22 17:48:55  2025-08-12 08:35:07               NaN
#  80  2025-07-22 17:49:01  2025-08-12 08:35:17               NaN
#  81  2025-07-22 17:49:05  2025-08-12 08:35:21               NaN
#
#  [82 rows x 11 columns],
#  'sepahankesht.com':                                                   url  \
#  0   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  1   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  2   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  3   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  4   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  5   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  6   https://sepahankesht.com/shop/%da%86%d8%a7%d9%...
#  7   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  8   https://sepahankesht.com/shop/%d9%87%db%8c%d9%...
#  9   https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  10  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  11  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  12  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  13  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  14  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  15  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  16  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  17  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  18  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  19  https://sepahankesht.com/shop/%da%86%d8%a7%d9%...
#  20  https://sepahankesht.com/shop/%da%86%d8%a7%d9%...
#  21  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  22  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  23  https://sepahankesht.com/shop/%d9%be%d8%aa%d8%...
#  24  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  25  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  26  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  27  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  28  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  29  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  30  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  31  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#  32  https://sepahankesht.com/shop/%da%a9%d9%88%d8%...
#
#                                                   name  \
#  0     کود هومی پاور پودری فیوچرکو بایوساینس ۱ کیلوگرم
#  1               کود هیومیک اسید مایع هیومولایف ۵ لیتر
#  2         کود هیومیک اسید گرانول هیومولایف ۲۵ کیلوگرم
#  3                کود اکوسالت (کاهنده شوری خاک) ۵ لیتر
#  4                کود نیچرمیک فیوچرکو بایوساینس ۵ لیتر
#  5         کود هومی پاور پلاس فیوچرکو بایوساینس ۵ لیتر
#  6   چالکود فرموکمپلکس همراه با گوگرد و عناصر ریزمغ...
#  7                      کود یارامیلا کمپلکس ۲۵ کیلوگرم
#  8                          هیومیک اسید فرتی وان AH 75
#  9                کود مایع هیومیک‌اسید نوتری تک ۵ لیتر
#  10     کود هیومیک دار NPK 20-5-10 هیومولایف 5 کیلوگرم
#  11     کود هیومیک دار NPK 12-5-20 هیومولایف 5 کیلوگرم
#  12               کود اصلاح کننده PH لوورسون (7 LOWER)
#  13          کود هیومیک و فولویک اسید هیومیستار ۵ لیتر
#  14         کود هیومیک اسید و فولویک اسید پابرا ۵ لیتر
#  15                 کود فولویک اسید نوتریویم ۱ کیلوگرم
#  16           کود ضدشوری گیاهان آپارتمانی ۶۰ میلی لیتر
#  17          کود ضد شوری فورنوترینت (Anti Salt) 5 لیتر
#  18               کود ضدشوری فرمولایف مدل دسالت ۵ لیتر
#  19                       چال کود پارس بلدر ۲۵ کیلوگرم
#  20                    چالکود پارسی لئون اس ۲۵ کیلوگرم
#  21      کود اسید هیومیک گیاهان آپارتمانی ۶۰ میلی لیتر
#  22                            کود ریزمغذی هوگر ۱ لیتر
#  23                              کود جلبک دریایی سیفول
#  24    کود فول‌فورس اس نوتریویم (FULLFORCE-S) 1کیلوگرم
#  25  کود مرغی مایع نیو داتیس آل (NEW DATIS ALL) حجم...
#  26          کود پودری اسیدهیومیک ASORIK وزن 1 کیلوگرم
#  27     کود داتیس فورنوترینت ارگانیک (کود مرغی) ۵ لیتر
#  28                 کود هیومیک اسید پابرا ۲.۵ کیلوگرمی
#  29          کود هیومیک اسید پودری هیومولایف ۱ کیلوگرم
#  30      کود هیومیک اسید مایع فورنوترینت OM حجم 5 لیتر
#  31   کود هیومیک اسید پودری هوموکسال ۹۵% وزن ۱ کیلوگرم
#  32                       کود مرغی مایع چیکوتی ۲۰ لیتر
#
#                            category    price  price_per_kg  amount_kg  \
#  0                   soil-modifying  1145760     1145760.0        1.0
#  1                      هیومیک-اسید  1155000      231000.0        5.0
#  2                      هیومیک-اسید  2204400       88176.0       25.0
#  3         anti-salinity-fertilizer  2481600      496320.0        5.0
#  4                   soil-modifying  2587200      517440.0        5.0
#  5                      هیومیک-اسید  2877600      575520.0        5.0
#  6                  fertilizer-hole  2970000      118800.0       25.0
#  7                  fertilizer-hole  6025800      241032.0       25.0
#  8                      هیومیک-اسید   194000           NaN        NaN
#  9                      هیومیک-اسید   377520       75504.0        5.0
#  10                     هیومیک-اسید   675840      135168.0        5.0
#  11                     هیومیک-اسید   675840      135168.0        5.0
#  12                  soil-modifying   774840           NaN        NaN
#  13                     هیومیک-اسید  1141800      228360.0        5.0
#  14                     هیومیک-اسید   411400       82280.0        5.0
#  15  powdered-folic-acid-fertilizer   776160      776160.0        1.0
#  16        anti-salinity-fertilizer    30000           NaN        NaN
#  17        anti-salinity-fertilizer   312000       62400.0        5.0
#  18        anti-salinity-fertilizer  1053360      210672.0        5.0
#  19                 fertilizer-hole   467500       18700.0       25.0
#  20                     هیومیک-اسید   561000       22440.0       25.0
#  21                     هیومیک-اسید    30000           NaN        NaN
#  22                     هیومیک-اسید   177600      177600.0        1.0
#  23                     هیومیک-اسید   187000      187000.0        1.0
#  24                     هیومیک-اسید   268800      268800.0        1.0
#  25                     هیومیک-اسید   326400       65280.0        5.0
#  26                     هیومیک-اسید   327600      327600.0        1.0
#  27                     هیومیک-اسید   393360       78672.0        5.0
#  28                     هیومیک-اسید   485760      194304.0        2.5
#  29                     هیومیک-اسید   498960      498960.0        1.0
#  30                     هیومیک-اسید   508200      101640.0        5.0
#  31                     هیومیک-اسید   513480      513480.0        1.0
#  32                     هیومیک-اسید  2085600      104280.0       20.0
#
#      last_price_update  is_available           created_at         last_updated  \
#  0                 NaN          True  2025-07-27 11:47:48  2025-07-27 16:16:19
#  1                 NaN          True  2025-07-27 11:47:51  2025-07-27 16:19:11
#  2                 NaN          True  2025-07-27 11:47:58  2025-07-27 16:19:13
#  3                 NaN          True  2025-07-27 11:48:07  2025-07-27 16:18:06
#  4                 NaN          True  2025-07-27 11:48:20  2025-07-27 16:16:25
#  5                 NaN          True  2025-07-27 11:48:24  2025-07-27 16:19:17
#  6                 NaN          True  2025-07-27 11:48:40  2025-07-27 16:18:45
#  7                 NaN          True  2025-07-27 11:50:37  2025-07-27 16:18:46
#  8                 NaN         False  2025-07-27 11:50:43  2025-07-27 16:19:18
#  9                 NaN         False  2025-07-27 11:55:23  2025-07-27 16:19:20
#  10                NaN         False  2025-07-27 11:55:26  2025-07-27 16:19:21
#  11                NaN         False  2025-07-27 11:55:30  2025-07-27 16:19:23
#  12                NaN         False  2025-07-27 11:55:51  2025-07-27 16:16:39
#  13                NaN         False  2025-07-27 11:55:56  2025-07-27 16:19:24
#  14                NaN          True  2025-07-27 11:56:08  2025-07-27 16:19:01
#  15                NaN          True  2025-07-27 12:14:57  2025-07-27 16:17:52
#  16                NaN          True  2025-07-27 12:15:50  2025-07-27 16:18:01
#  17                NaN          True  2025-07-27 12:15:54  2025-07-27 16:18:03
#  18                NaN          True  2025-07-27 12:15:58  2025-07-27 16:18:05
#  19                NaN          True  2025-07-27 12:16:39  2025-07-27 16:18:40
#  20                NaN          True  2025-07-27 12:16:44  2025-07-27 16:19:05
#  21                NaN          True  2025-07-27 12:16:57  2025-07-27 16:18:50
#  22                NaN          True  2025-07-27 12:17:01  2025-07-27 16:18:51
#  23                NaN          True  2025-07-27 12:17:06  2025-07-27 16:18:53
#  24                NaN          True  2025-07-27 12:17:10  2025-07-27 16:18:55
#  25                NaN          True  2025-07-27 12:17:12  2025-07-27 16:18:56
#  26                NaN          True  2025-07-27 12:17:18  2025-07-27 16:18:58
#  27                NaN          True  2025-07-27 12:17:22  2025-07-27 16:19:00
#  28                NaN          True  2025-07-27 12:17:31  2025-07-27 16:19:03
#  29                NaN          True  2025-07-27 12:17:38  2025-07-27 16:19:07
#  30                NaN          True  2025-07-27 12:17:40  2025-07-27 16:19:08
#  31                NaN          True  2025-07-27 12:17:46  2025-07-27 16:19:10
#  32                NaN          True  2025-07-27 12:17:55  2025-07-27 16:19:15
#
#      product_menu_url
#  0                NaN
#  1                NaN
#  2                NaN
#  3                NaN
#  4                NaN
#  5                NaN
#  6                NaN
#  7                NaN
#  8                NaN
#  9                NaN
#  10               NaN
#  11               NaN
#  12               NaN
#  13               NaN
#  14               NaN
#  15               NaN
#  16               NaN
#  17               NaN
#  18               NaN
#  19               NaN
#  20               NaN
#  21               NaN
#  22               NaN
#  23               NaN
#  24               NaN
#  25               NaN
#  26               NaN
#  27               NaN
#  28               NaN
#  29               NaN
#  30               NaN
#  31               NaN
#  32               NaN  ,
#  'royalkesht.com':                                     url                      name  \
#  0  https://royalkesht.com/vermicompost/  کود ورمی کمپوست سوپر PLS
#  1  https://royalkesht.com/vermicompost/    کود ورمی کمپوست معمولی
#  2  https://royalkesht.com/vermicompost/   کود ورمی کمپوست غنی شده
#
#            category  price price_per_kg  amount_kg  last_price_update  \
#  0  کود ورمی کمپوست  ۴,۰۰۰        ۴,۰۰۰        NaN                NaN
#  1  کود ورمی کمپوست  ۳,۰۰۰        ۳,۰۰۰        NaN                NaN
#  2  کود ورمی کمپوست  ۳,۵۰۰        ۳,۵۰۰        NaN                NaN
#
#     is_available           created_at         last_updated  product_menu_url
#  0           NaN  2025-07-28 14:54:16  2025-08-12 09:34:07               NaN
#  1           NaN  2025-07-29 14:45:17  2025-08-12 09:34:00               NaN
#  2           NaN  2025-07-29 14:45:19  2025-08-12 09:34:04               NaN  ,
#  'basalam.com':                                                     url  \
#  0        https://basalam.com/greenrose/product/11745865
#  1     https://basalam.com/arzankadeh7berke/product/1...
#  2     https://basalam.com/goldan.felezi/product/1507...
#  3     https://basalam.com/almase_sorkh/product/11141428
#  4            https://basalam.com/igool/product/16423331
#  ...                                                 ...
#  6678  https://basalam.com/dashtesabz-shop/product/12...
#  6679  https://basalam.com/dashtesabz-shop/product/15...
#  6680    https://basalam.com/rasha_drog/product/15213430
#  6681    https://basalam.com/rasha_drog/product/15213420
#  6682    https://basalam.com/rasha_drog/product/15213895
#
#                                                     name  category    price  \
#  0                  خاک و کود آماده کاشت تای سیز 4 لیتری       NaN   450000
#  1     خاک و کود بستر مخصوص گیاهان آبزی و میگوها اوشن...       NaN  1223800
#  2                          خاک و کود آماده کاشت 4 لیتری       NaN   402000
#  3               خاک و کود آماده کاشت گیلدا بسته 4 لیتری       NaN  1100000
#  4     خاک کود آفت کش و گلدان پلیمری پک تعویض گلدان ک...       NaN   499000
#  ...                                                 ...       ...      ...
#  6678                  کود نیتروژن پتاسیم NK60 ایکس گرین       NaN   403000
#  6679                         کود کامل 10 x شوک یک لیتری       NaN   570000
#  6680  گیاه دم اسب با کیفیت عالی، بار امسالی و تازه(5...       NaN    76000
#  6681  ریشه شیرین بیان با کیفیت عالی، بار امسالی و تا...       NaN    82500
#  6682  صمغ مرمکی با کیفیت عالی، بار امسالی و تازه(250...       NaN  1775400
#
#        price_per_kg  amount_kg  last_price_update is_available  \
#  0     2.812500e+05       1.60                NaN         True
#  1     4.079333e+05       3.00                NaN         True
#  2     1.005000e+05       4.00                NaN         True
#  3     4.782609e+05       2.30                NaN         True
#  4              NaN        NaN                NaN         True
#  ...            ...        ...                ...          ...
#  6678  4.030000e+05       1.00                NaN         True
#  6679           NaN        NaN                NaN         True
#  6680  1.520000e+06       0.05                NaN         True
#  6681  8.250000e+05       0.10                NaN         True
#  6682  7.101600e+06       0.25                NaN         True
#
#                 created_at         last_updated  \
#  0     2025-08-04 10:38:26  2025-08-12 10:36:27
#  1     2025-08-04 10:38:28  2025-08-12 16:11:52
#  2     2025-08-04 10:38:31  2025-08-12 10:36:24
#  3     2025-08-04 10:38:34  2025-08-12 10:36:16
#  4     2025-08-04 10:38:37  2025-08-12 16:11:57
#  ...                   ...                  ...
#  6678  2025-08-13 03:15:50  2025-08-13 03:15:50
#  6679  2025-08-13 03:15:57  2025-08-13 03:15:57
#  6680  2025-08-13 03:16:06  2025-08-13 03:16:06
#  6681  2025-08-13 03:16:14  2025-08-13 03:16:14
#  6682  2025-08-13 03:16:22  2025-08-13 03:16:22
#
#                                         product_menu_url
#  0     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  1     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  2     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  3     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  4     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  ...                                                 ...
#  6678  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  6679  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  6680  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  6681  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#  6682  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
#
#  [6683 rows x 11 columns]}

# %%
# Concatenate all the data in the 
dataFrame = pd.DataFrame()
for data in df.values():
    dataFrame = pd.concat([data,dataFrame],ignore_index=True)

dataFrame
# Out:
#                                                     url  \
# 0        https://basalam.com/greenrose/product/11745865
# 1     https://basalam.com/arzankadeh7berke/product/1...
# 2     https://basalam.com/goldan.felezi/product/1507...
# 3     https://basalam.com/almase_sorkh/product/11141428
# 4            https://basalam.com/igool/product/16423331
# ...                                                 ...
# 8868  https://agriplus.ir/Product/BKP-14233/%d9%be%d...
# 8869  https://agriplus.ir/Product/BKP-37836/rooty-sg15/
# 8870  https://agriplus.ir/Product/BKP-24561/rooting-...
# 8871  https://agriplus.ir/Product/BKP-36035/rooty-ho...
# 8872  https://agriplus.ir/Product/BKP-37832/rooty-sy...
#
#                                                    name          category  \
# 0                  خاک و کود آماده کاشت تای سیز 4 لیتری               NaN
# 1     خاک و کود بستر مخصوص گیاهان آبزی و میگوها اوشن...               NaN
# 2                          خاک و کود آماده کاشت 4 لیتری               NaN
# 3               خاک و کود آماده کاشت گیلدا بسته 4 لیتری               NaN
# 4     خاک کود آفت کش و گلدان پلیمری پک تعویض گلدان ک...               NaN
# ...                                                 ...               ...
# 8868                         پودر جیبرلین BERELEX ۴۰ SG  هورمون رشد گیاهی
# 8869         هورمون ریشه زایی هلندی روتی SG15 اگری پلاس  هورمون رشد گیاهی
# 8870                هورمون ریشه زایی هندی L30 اگری پلاس  هورمون رشد گیاهی
# 8871         هورمون ریشه‌ زایی هلندی روتی L30 اگری پلاس  هورمون رشد گیاهی
# 8872         هورمون ریشه زایی غلیظ روتی Syrup اگری پلاس  هورمون رشد گیاهی
#
#         price   price_per_kg  amount_kg  last_price_update is_available  \
# 0      450000       281250.0        1.6                NaN         True
# 1     1223800  407933.333333        3.0                NaN         True
# 2      402000       100500.0        4.0                NaN         True
# 3     1100000  478260.869565        2.3                NaN         True
# 4      499000            NaN        NaN                NaN         True
# ...       ...            ...        ...                ...          ...
# 8868      NaN            NaN        NaN                NaN        False
# 8869      NaN            NaN        NaN                NaN        False
# 8870      NaN            NaN        NaN                NaN        False
# 8871      NaN            NaN        NaN                NaN        False
# 8872      NaN            NaN        NaN                NaN        False
#
#                created_at         last_updated  \
# 0     2025-08-04 10:38:26  2025-08-12 10:36:27
# 1     2025-08-04 10:38:28  2025-08-12 16:11:52
# 2     2025-08-04 10:38:31  2025-08-12 10:36:24
# 3     2025-08-04 10:38:34  2025-08-12 10:36:16
# 4     2025-08-04 10:38:37  2025-08-12 16:11:57
# ...                   ...                  ...
# 8868  2025-07-22 16:34:21  2025-08-12 09:33:25
# 8869  2025-08-12 09:32:35  2025-08-12 09:32:35
# 8870  2025-08-12 09:32:48  2025-08-12 09:32:48
# 8871  2025-08-12 09:32:54  2025-08-12 09:32:54
# 8872  2025-08-12 09:33:06  2025-08-12 09:33:06
#
#                                        product_menu_url  _pk
# 0     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 3     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 4     https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# ...                                                 ...  ...
# 8868                                                NaN  NaN
# 8869                                                NaN  NaN
# 8870                                                NaN  NaN
# 8871                                                NaN  NaN
# 8872                                                NaN  NaN
#
# [8873 rows x 12 columns]

# %%
# DATAAAAAAAAAAAAAAAAAAAAAAA SILICATTTTTTTTTTTTTTTTTTTTT
# DATAAAAAAAAAAAAAAAAAAAAAAA SILICATTTTTTTTTTTTTTTTTTTTT


dataFrame[dataFrame["name"].str.contains("سیلیکات")]
# Out:
#                                                     url  \
# 958      https://basalam.com/giahpezshk/product/8308606
# 1013       https://basalam.com/kudmod1/product/15794971
# 1286    https://basalam.com/technoland/product/21076068
# 1375    https://basalam.com/shimistore/product/24132609
# 1385    https://basalam.com/toluoesabz/product/22222267
# 1459         https://basalam.com/allk1/product/21180232
# 1713     https://basalam.com/humicacid/product/21069005
# 1899      https://basalam.com/sambaire/product/17318617
# 2120  https://basalam.com/keshavarzi_arman/product/2...
# 2290       https://basalam.com/kudbest/product/21270338
# 2297   https://basalam.com/kud-orginal/product/19666229
# 2304   https://basalam.com/kud-orginal/product/19747958
# 2318      https://basalam.com/kud-land/product/21300553
# 2620      https://basalam.com/caseshik/product/21891441
# 2913  https://basalam.com/dashtesabz-shop/product/17...
# 3089       https://basalam.com/koudaram/product/7649992
# 3091      https://basalam.com/koudaram/product/23281942
# 4081  https://basalam.com/golbaran1401/product/25113681
# 4838  https://basalam.com/zerafat_shop/product/21818392
# 5024       https://basalam.com/allk1vip/product/8739237
# 5032    https://basalam.com/plant.kala/product/15491633
# 5471  https://basalam.com/toranj_fertiliser_pesticid...
# 5628   https://basalam.com/qaranfil.ir/product/21411582
# 6424    https://basalam.com/ferti_land/product/23330083
# 6511       https://basalam.com/koudaram/product/7650030
# 7170  https://torob.com/p/28be7b35-5689-415c-9162-3e...
# 7212  https://torob.com/p/c4605306-481c-4626-bbe6-ae...
# 7314  https://torob.com/p/a3bafbf9-0600-4c93-b9f7-47...
# 7354  https://torob.com/p/33aff345-29da-4984-946c-31...
# 7383  https://torob.com/p/95817e87-1a4d-48e3-a4d1-9a...
# 7569  https://torob.com/p/d1cf798d-2d46-45c2-90cd-2f...
# 7597  https://torob.com/p/51b55bf8-fd10-4dfa-830e-47...
# 7623  https://torob.com/p/fb6b0bbe-5b95-45df-ab73-fc...
# 7780  https://torob.com/p/99faa402-3f4a-4a04-82f0-e5...
# 7784  https://torob.com/p/735737f7-0be1-47d2-aaf3-86...
# 7845  https://torob.com/p/fe7d99b9-9ef2-4193-9f03-dd...
# 8024  https://torob.com/p/5508fb29-9f64-43ed-8531-d4...
# 8032  https://torob.com/p/c6358129-0e36-43b6-a19d-8d...
# 8197  https://torob.com/p/bcf958ea-7783-47d4-8352-a6...
# 8235  https://torob.com/p/f3ddc90b-8fd5-4fb1-9f92-6d...
# 8249  https://torob.com/p/6259c297-5f01-476a-97cf-aa...
# 8309  https://torob.com/p/a3bafbf9-0600-4c93-b9f7-47...
# 8486  https://torob.com/p/1e948a3f-688b-4ae1-a809-c9...
# 8498  https://torob.com/p/d56cadb1-7d56-4d97-b5da-47...
#
#                                                    name category      price  \
# 958   کود پودری سیلیکات پتاسیم گرین شیلد تحت لیسانس ...      NaN    325٬000
# 1013                     کود سیلیکات پتاسیم 1 لیتری شوک      NaN    370٬000
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...      NaN     420000
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...      NaN     175000
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...      NaN     480000
# 1459    کود ارگانیک، کود سیلیکات پتاسیم شوک 1 لیتری اصل      NaN    288٬000
# 1713  کود سیلیکات پتاسیم مایع اکسپلود اصل 1 لیتری (پ...      NaN    300٬000
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...      NaN     255600
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس      NaN     385000
# 2290      کود نانو، کود سیلیکات پتاسیم مایع شوک 1 لیتری      NaN    288٬000
# 2297                کود سیلیکات پتاسیم شوک 5 لیتری نانو      NaN  1٬350٬000
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری      NaN     400000
# 2318           کود سیلیکات پتاسیم مایع شوک 20 لیتری اصل      NaN  2٬600٬000
# 2620                         کود سیلیکات کلسیم یا کلسیل      NaN     390000
# 2913                            کود سیلیکات پتاسیم زایز      NaN    1175000
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل      NaN     400000
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل      NaN    3700000
# 4081              کود مایع،سیلیکات پتاسیم ورساد اسپانیا      NaN     460000
# 4838                        کود سیلیکات پتاسیم اگرولایو      NaN     345000
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...      NaN    1800000
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع،...      NaN     500000
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان      NaN     250000
# 5628                                 کود سیلیکات پتاسیم      NaN     450000
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک      NaN     580000
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...      NaN    1500000
# 7170                      کود سیلیکات پتاسیم مایع G.SIL      NaN     460000
# 7212                        کود پتاسیم سیلیکات مایع شوک      NaN    2800000
# 7314                                     سیلیکات پتاسیم      NaN    1200000
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر      NaN     735000
# 7383                        کود سیلیکات پتاسیم WE GUARD      NaN     980000
# 7569       سیلیکات پتاسیم باراکودا گلسم گرگان. یک لیتری      NaN     345000
# 7597                        کود سیلیکات پتاسیم اگرولایو      NaN     350000
# 7623                         کود سیلیکات پتاسیم وپروفرت      NaN     405000
# 7780                    سیلیکات پتاسیم سیترال (۱ لیتری)      NaN     350000
# 7784                    سیلیکات پتاسیم پروسیل (۱ لیتری)      NaN     500000
# 7845                                     پتاسیم سیلیکات      NaN     345000
# 8024            قرص جوشان سیلیکا نوسبو / سیلیکات پتاسیم      NaN    1000000
# 8032  سیلیکات پتاسیم استند اگری کم استرالیا | (STAND...      NaN    1350000
# 8197  کود پرو سیلیکات گروتک نیم لیتری pro silicate 5...      NaN    1228500
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان ۵ لیتری      NaN    1180000
# 8249        سیلیکات پتاسیم برتانی(گروه کابالرو) ایتالیا      NaN     480000
# 8309                             سیلیکات پتاسیم(۵لیتری)      NaN    1200000
# 8486  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...      NaN     420000
# 8498                          کود سیلیکات پتاسیم اگروفر      NaN    1327000
#
#      price_per_kg  amount_kg  last_price_update is_available  \
# 958           NaN        NaN                NaN          NaN
# 1013          NaN        NaN                NaN          NaN
# 1286     420000.0        1.0                NaN         True
# 1375     175000.0        1.0                NaN         True
# 1385     480000.0        1.0                NaN         True
# 1459          NaN        NaN                NaN          NaN
# 1713          NaN        NaN                NaN          NaN
# 1899     255600.0        1.0                NaN         True
# 2120     385000.0        1.0                NaN         True
# 2290          NaN        NaN                NaN          NaN
# 2297          NaN        NaN                NaN          NaN
# 2304     400000.0        1.0                NaN         True
# 2318          NaN        NaN                NaN          NaN
# 2620     390000.0        1.0                NaN         True
# 2913    1175000.0        1.0                NaN         True
# 3089     400000.0        1.0                NaN         True
# 3091      18500.0      200.0                NaN         True
# 4081     460000.0        1.0                NaN         True
# 4838     345000.0        1.0                NaN         True
# 5024     360000.0        5.0                NaN         True
# 5032     500000.0        1.0                NaN         True
# 5471     250000.0        1.0                NaN         True
# 5628          NaN        NaN                NaN         True
# 6424     580000.0        1.0                NaN         True
# 6511     300000.0        5.0                NaN         True
# 7170          NaN        NaN                NaN         True
# 7212          NaN        NaN                NaN         True
# 7314          NaN        NaN                NaN         True
# 7354     147000.0        5.0                NaN         True
# 7383          NaN        NaN                NaN         True
# 7569          NaN        NaN                NaN         True
# 7597          NaN        NaN                NaN         True
# 7623          NaN        NaN                NaN         True
# 7780     350000.0        1.0                NaN         True
# 7784     500000.0        1.0                NaN         True
# 7845          NaN        NaN                NaN         True
# 8024          NaN        NaN                NaN         True
# 8032          NaN        NaN                NaN         True
# 8197          NaN        NaN                NaN         True
# 8235     236000.0        5.0                NaN         True
# 8249          NaN        NaN                NaN         True
# 8309     240000.0        5.0                NaN         True
# 8486          NaN        NaN                NaN         True
# 8498          NaN        NaN                NaN         True
#
#                created_at         last_updated  \
# 958   2025-08-04 11:46:32  2025-08-04 11:46:32
# 1013  2025-08-04 11:49:09  2025-08-04 11:49:09
# 1286  2025-08-04 12:03:52  2025-08-12 17:06:33
# 1375  2025-08-04 12:08:41  2025-08-12 17:08:40
# 1385  2025-08-04 12:09:15  2025-08-12 17:09:14
# 1459  2025-08-04 12:13:19  2025-08-04 12:13:19
# 1713  2025-08-04 12:28:12  2025-08-04 12:28:12
# 1899  2025-08-04 12:39:14  2025-08-12 18:19:44
# 2120  2025-08-04 12:52:19  2025-08-12 18:18:33
# 2290  2025-08-04 13:02:42  2025-08-04 13:02:42
# 2297  2025-08-04 13:03:07  2025-08-04 13:03:07
# 2304  2025-08-04 13:03:33  2025-08-12 18:23:19
# 2318  2025-08-04 13:04:25  2025-08-04 13:04:25
# 2620  2025-08-12 14:10:10  2025-08-12 18:32:51
# 2913  2025-08-12 15:42:01  2025-08-12 19:15:28
# 3089  2025-08-12 16:05:38  2025-08-12 19:25:35
# 3091  2025-08-12 16:06:00  2025-08-12 19:25:44
# 4081  2025-08-12 21:10:13  2025-08-12 21:10:13
# 4838  2025-08-12 22:38:38  2025-08-12 22:38:38
# 5024  2025-08-12 22:59:20  2025-08-12 22:59:20
# 5032  2025-08-12 23:00:12  2025-08-12 23:00:12
# 5471  2025-08-13 00:03:44  2025-08-13 00:03:44
# 5628  2025-08-13 00:23:03  2025-08-13 00:23:03
# 6424  2025-08-13 02:34:27  2025-08-13 02:34:27
# 6511  2025-08-13 02:48:15  2025-08-13 02:48:15
# 7170  2025-07-22 16:46:08  2025-07-27 16:50:47
# 7212  2025-07-22 16:46:22  2025-07-27 16:51:25
# 7314  2025-07-22 16:47:00  2025-07-22 16:47:00
# 7354  2025-07-22 16:47:16  2025-07-27 16:52:05
# 7383  2025-07-22 16:47:29  2025-07-27 16:54:12
# 7569  2025-07-22 16:49:02  2025-07-27 16:53:53
# 7597  2025-07-22 16:49:18  2025-07-27 17:08:21
# 7623  2025-07-22 16:49:33  2025-07-27 17:01:15
# 7780  2025-07-22 16:51:13  2025-07-27 17:12:11
# 7784  2025-07-22 16:51:16  2025-07-27 16:55:59
# 7845  2025-07-22 16:51:59  2025-07-27 17:11:02
# 8024  2025-07-22 16:54:17  2025-07-22 16:54:17
# 8032  2025-07-22 16:54:24  2025-07-27 17:09:29
# 8197  2025-07-22 16:56:50  2025-07-22 16:56:50
# 8235  2025-07-22 16:57:25  2025-07-22 16:57:25
# 8249  2025-07-22 16:57:39  2025-07-27 17:10:12
# 8309  2025-07-27 16:53:36  2025-07-27 16:53:36
# 8486  2025-07-27 17:08:41  2025-07-27 17:08:41
# 8498  2025-07-27 17:09:34  2025-07-27 17:09:34
#
#                                        product_menu_url  _pk
# 958                                                 NaN  NaN
# 1013                                                NaN  NaN
# 1286  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1375  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1385  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1459                                                NaN  NaN
# 1713                                                NaN  NaN
# 1899  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2120  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2290                                                NaN  NaN
# 2297                                                NaN  NaN
# 2304  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2318                                                NaN  NaN
# 2620  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2913  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 3089  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 3091  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 4081  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 4838  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5024  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5032  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5471  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5628  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 6424  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 6511  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 7170                                                NaN  NaN
# 7212                                                NaN  NaN
# 7314                                                NaN  NaN
# 7354                                                NaN  NaN
# 7383                                                NaN  NaN
# 7569                                                NaN  NaN
# 7597                                                NaN  NaN
# 7623                                                NaN  NaN
# 7780                                                NaN  NaN
# 7784                                                NaN  NaN
# 7845                                                NaN  NaN
# 8024                                                NaN  NaN
# 8032                                                NaN  NaN
# 8197                                                NaN  NaN
# 8235                                                NaN  NaN
# 8249                                                NaN  NaN
# 8309                                                NaN  NaN
# 8486                                                NaN  NaN
# 8498                                                NaN  NaN

# %%
df = dataFrame

df.dropna(subset=['price_per_kg'],inplace=True)
df = df.drop(labels="created_at",axis=1)
df = df.drop(labels="last_updated",axis=1)
df.to_csv("concatenated_excel/fullRawExcel.csv")

df.drop("url",axis=1,inplace=True)

# Filter some irrelevent keywords
keywords = ["خاک", "سم", "قارچ", "حشره", "علف", "صمغ"]
pattern = "|".join(keywords) 

df = df[~df.iloc[:,0].astype(str).str.contains(pattern)]

# %%
# DATAAAAAAAAAAAAAAAAAAAAAAA SILICATTTTTTTTTTTTTTTTTTTTT
# DATAAAAAAAAAAAAAAAAAAAAAAA SILICATTTTTTTTTTTTTTTTTTTTT


df[df["name"].str.contains("سیلیکات")]
# Out:
#                                                    name category    price  \
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...      NaN   420000
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...      NaN   175000
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...      NaN   480000
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...      NaN   255600
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس      NaN   385000
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری      NaN   400000
# 2620                         کود سیلیکات کلسیم یا کلسیل      NaN   390000
# 2913                            کود سیلیکات پتاسیم زایز      NaN  1175000
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل      NaN   400000
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل      NaN  3700000
# 4081              کود مایع،سیلیکات پتاسیم ورساد اسپانیا      NaN   460000
# 4838                        کود سیلیکات پتاسیم اگرولایو      NaN   345000
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...      NaN  1800000
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع،...      NaN   500000
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان      NaN   250000
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک      NaN   580000
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...      NaN  1500000
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر      NaN   735000
# 7780                    سیلیکات پتاسیم سیترال (۱ لیتری)      NaN   350000
# 7784                    سیلیکات پتاسیم پروسیل (۱ لیتری)      NaN   500000
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان ۵ لیتری      NaN  1180000
# 8309                             سیلیکات پتاسیم(۵لیتری)      NaN  1200000
#
#      price_per_kg  amount_kg  last_price_update is_available  \
# 1286     420000.0        1.0                NaN         True
# 1375     175000.0        1.0                NaN         True
# 1385     480000.0        1.0                NaN         True
# 1899     255600.0        1.0                NaN         True
# 2120     385000.0        1.0                NaN         True
# 2304     400000.0        1.0                NaN         True
# 2620     390000.0        1.0                NaN         True
# 2913    1175000.0        1.0                NaN         True
# 3089     400000.0        1.0                NaN         True
# 3091      18500.0      200.0                NaN         True
# 4081     460000.0        1.0                NaN         True
# 4838     345000.0        1.0                NaN         True
# 5024     360000.0        5.0                NaN         True
# 5032     500000.0        1.0                NaN         True
# 5471     250000.0        1.0                NaN         True
# 6424     580000.0        1.0                NaN         True
# 6511     300000.0        5.0                NaN         True
# 7354     147000.0        5.0                NaN         True
# 7780     350000.0        1.0                NaN         True
# 7784     500000.0        1.0                NaN         True
# 8235     236000.0        5.0                NaN         True
# 8309     240000.0        5.0                NaN         True
#
#                                        product_menu_url  _pk
# 1286  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1375  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1385  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 1899  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2120  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2304  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2620  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 2913  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 3089  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 3091  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 4081  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 4838  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5024  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5032  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 5471  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 6424  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 6511  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 7354                                                NaN  NaN
# 7780                                                NaN  NaN
# 7784                                                NaN  NaN
# 8235                                                NaN  NaN
# 8309                                                NaN  NaN

# %%
df = df.drop(labels="last_price_update",axis=1)
df
# Out:
#                                                    name          category  \
# 673   اسید هیومیک پودری 50 گرمی و ( 10 کیلویی فرومیتو )               NaN
# 904   کود سولفات پتاسیم فلورامی 100 گرمی (potassium ...               NaN
# 906                             کود هیومیک اسید نیکوبذر               NaN
# 910   کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فناو...               NaN
# 918   کود مایع مخصوص گل بابا آدم برند تایمکس حجم 150...               NaN
# ...                                                 ...               ...
# 8846                      کود مایع بمباردیر شوگر کیمیتک          کود کامل
# 8851                         کود مایع محرک رشد بمباردیر          کود کامل
# 8862         هورمون شاخه‌ زایی شوتی (®Shooty) اگری پلاس  هورمون رشد گیاهی
# 8864  هورمون پاکوتاهی - گلدهی کتولی (®Cotooly) اگری ...  هورمون رشد گیاهی
# 8866              هورمون گلدهی فلوری (®Flory) اگری پلاس  هورمون رشد گیاهی
#
#          price    price_per_kg  amount_kg is_available  \
# 673      75000       1500000.0      0.050         True
# 904      41000        410000.0      0.100         True
# 906      25000  3571428.571429      0.007         True
# 910      40000  1333333.333333      0.030         True
# 918      89000   593333.333333      0.150         True
# ...        ...             ...        ...          ...
# 8846  13068000      13068000.0      1.000         True
# 8851  10920000      10920000.0      1.000         True
# 8862   5170000         51700.0    100.000         True
# 8864   3100000         31000.0    100.000         True
# 8866  12400000         49600.0    250.000         True
#
#                                        product_menu_url  _pk
# 673   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 904   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 906   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 910   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# 918   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...  NaN
# ...                                                 ...  ...
# 8846                                                NaN  NaN
# 8851                                                NaN  NaN
# 8862                                                NaN  NaN
# 8864                                                NaN  NaN
# 8866                                                NaN  NaN
#
# [4444 rows x 8 columns]

# %%
df.drop("_pk",axis=1,inplace=True)
df
# Out:
#                                                    name          category  \
# 673   اسید هیومیک پودری 50 گرمی و ( 10 کیلویی فرومیتو )               NaN
# 904   کود سولفات پتاسیم فلورامی 100 گرمی (potassium ...               NaN
# 906                             کود هیومیک اسید نیکوبذر               NaN
# 910   کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فناو...               NaN
# 918   کود مایع مخصوص گل بابا آدم برند تایمکس حجم 150...               NaN
# ...                                                 ...               ...
# 8846                      کود مایع بمباردیر شوگر کیمیتک          کود کامل
# 8851                         کود مایع محرک رشد بمباردیر          کود کامل
# 8862         هورمون شاخه‌ زایی شوتی (®Shooty) اگری پلاس  هورمون رشد گیاهی
# 8864  هورمون پاکوتاهی - گلدهی کتولی (®Cotooly) اگری ...  هورمون رشد گیاهی
# 8866              هورمون گلدهی فلوری (®Flory) اگری پلاس  هورمون رشد گیاهی
#
#          price    price_per_kg  amount_kg is_available  \
# 673      75000       1500000.0      0.050         True
# 904      41000        410000.0      0.100         True
# 906      25000  3571428.571429      0.007         True
# 910      40000  1333333.333333      0.030         True
# 918      89000   593333.333333      0.150         True
# ...        ...             ...        ...          ...
# 8846  13068000      13068000.0      1.000         True
# 8851  10920000      10920000.0      1.000         True
# 8862   5170000         51700.0    100.000         True
# 8864   3100000         31000.0    100.000         True
# 8866  12400000         49600.0    250.000         True
#
#                                        product_menu_url
# 673   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 904   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 906   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 910   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 918   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# ...                                                 ...
# 8846                                                NaN
# 8851                                                NaN
# 8862                                                NaN
# 8864                                                NaN
# 8866                                                NaN
#
# [4444 rows x 7 columns]

# %%
normalizer = PersianNumberNormalizer()
df['name'] = normalizer.convert(df['name'])

# %%
# convert all of the prices to float
df["price_per_kg"] = pd.to_numeric(df["price_per_kg"], errors="coerce").astype(float)

# %%
df
# Out:
#                                                    name          category  \
# 673   اسید هیومیک پودری 50 گرمی و ( 10 کیلویی فرومیتو )               NaN
# 904   کود سولفات پتاسیم فلورامی 100 گرمی (potassium ...               NaN
# 906                             کود هیومیک اسید نیکوبذر               NaN
# 910   کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فناو...               NaN
# 918   کود مایع مخصوص گل بابا آدم برند تایمکس حجم 150...               NaN
# ...                                                 ...               ...
# 8846                      کود مایع بمباردیر شوگر کیمیتک          کود کامل
# 8851                         کود مایع محرک رشد بمباردیر          کود کامل
# 8862         هورمون شاخه‌ زایی شوتی (®Shooty) اگری پلاس  هورمون رشد گیاهی
# 8864  هورمون پاکوتاهی - گلدهی کتولی (®Cotooly) اگری ...  هورمون رشد گیاهی
# 8866              هورمون گلدهی فلوری (®Flory) اگری پلاس  هورمون رشد گیاهی
#
#          price  price_per_kg  amount_kg is_available  \
# 673      75000  1.500000e+06      0.050         True
# 904      41000  4.100000e+05      0.100         True
# 906      25000  3.571429e+06      0.007         True
# 910      40000  1.333333e+06      0.030         True
# 918      89000  5.933333e+05      0.150         True
# ...        ...           ...        ...          ...
# 8846  13068000  1.306800e+07      1.000         True
# 8851  10920000  1.092000e+07      1.000         True
# 8862   5170000  5.170000e+04    100.000         True
# 8864   3100000  3.100000e+04    100.000         True
# 8866  12400000  4.960000e+04    250.000         True
#
#                                        product_menu_url
# 673   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 904   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 906   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 910   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 918   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# ...                                                 ...
# 8846                                                NaN
# 8851                                                NaN
# 8862                                                NaN
# 8864                                                NaN
# 8866                                                NaN
#
# [4444 rows x 7 columns]

# %%
raw_source_df = pd.read_excel(io="source/raw_source_of_fertilizer.xlsx")

# %% [markdown]
# **Filter specific fertilizer**

# %% [markdown]
# npk

# %%
# Compile all positive patterns into one regex
include_pattern = r"(npk|n\s*p\s*k|کامل)"
exclude_pattern = r"(خاک)"

filtered_df_npk = df[
    df['name'].str.lower().str.contains(include_pattern, regex=True, na=False)
    & ~df['name'].str.contains(exclude_pattern, regex=True, na=False)
]
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8828\3938185361.py:6: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   df['name'].str.lower().str.contains(include_pattern, regex=True, na=False)
# C:\Users\pc\AppData\Local\Temp\ipykernel_8828\3938185361.py:7: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   & ~df['name'].str.contains(exclude_pattern, regex=True, na=False)

# %%
raw_source_df.columns
# Out:
# Index(['sub_input_code', 'input_code', 'Name_of_fertilizer',
#        'Group_of_fertilizer', 'Real_Name_of_fertilizer', 'Minimum_Price(Kg)',
#        'Maximum_Price(Kg)', 'Exact_Price(Kg)', 'Sources', 'sources_unique',
#        'Group_of_fertilizer_unique'],
#       dtype='object')

# %%
raw_source_df_npk_filtered = raw_source_df[raw_source_df["input_code"] == 17]
raw_source_df_npk_filtered
# Out:
#     sub_input_code  input_code Name_of_fertilizer   Group_of_fertilizer  \
# 53             111          17             17-111  کود های کامل (N-P-K)
# 54             112          17             17-112  کود های کامل (N-P-K)
# 55             113          17             17-113  کود های کامل (N-P-K)
# 56             114          17             17-114  کود های کامل (N-P-K)
# 57             115          17             17-115  کود های کامل (N-P-K)
# 58             116          17             17-116  کود های کامل (N-P-K)
# 59             117          17             17-117  کود های کامل (N-P-K)
# 60             118          17             17-118  کود های کامل (N-P-K)
# 61             119          17             17-119  کود های کامل (N-P-K)
# 62             120          17             17-120  کود های کامل (N-P-K)
# 63             121          17             17-121  کود های کامل (N-P-K)
# 64             122          17             17-122  کود های کامل (N-P-K)
# 65             123          17             17-123  کود های کامل (N-P-K)
# 66             124          17             17-124  کود های کامل (N-P-K)
# 67             125          17             17-125  کود های کامل (N-P-K)
# 68             126          17             17-126  کود های کامل (N-P-K)
# 69             127          17             17-127  کود های کامل (N-P-K)
# 70             128          17             17-128  کود های کامل (N-P-K)
# 71             129          17             17-129  کود های کامل (N-P-K)
# 72             130          17             17-130  کود های کامل (N-P-K)
# 73             131          17             17-131  کود های کامل (N-P-K)
# 74             132          17             17-132  کود های کامل (N-P-K)
# 75             133          17             17-133  کود های کامل (N-P-K)
# 76             134          17             17-134  کود های کامل (N-P-K)
# 77             135          17             17-135  کود های کامل (N-P-K)
# 78             136          17             17-136  کود های کامل (N-P-K)
# 79             137          17             17-137  کود های کامل (N-P-K)
# 80             138          17             17-138  کود های کامل (N-P-K)
# 81             139          17             17-139  کود های کامل (N-P-K)
# 82             140          17             17-140  کود های کامل (N-P-K)
# 83             141          17             17-141  کود های کامل (N-P-K)
# 84             142          17             17-142  کود های کامل (N-P-K)
# 85             143          17             17-143  کود های کامل (N-P-K)
# 86             144          17             17-144  کود های کامل (N-P-K)
# 87             145          17             17-145  کود های کامل (N-P-K)
# 88             146          17             17-146  کود های کامل (N-P-K)
# 89             147          17             17-147  کود های کامل (N-P-K)
# 90             148          17             17-148  کود های کامل (N-P-K)
# 91             149          17             17-149  کود های کامل (N-P-K)
# 92             150          17             17-150  کود های کامل (N-P-K)
# 93             151          17             17-151  کود های کامل (N-P-K)
#
#    Real_Name_of_fertilizer  Minimum_Price(Kg)  Maximum_Price(Kg)  \
# 53                20-20-20             900000            2300000
# 54                12-12-36            1690000            2480000
# 55                10-52-10            1700000            2956000
# 56                 15-5-40            1690000            2480000
# 57                  5-5-15            1690000            2480000
# 58                 15-5-30            1690000            2480000
# 59                 14-8-30            1690000            2480000
# 60                 18-8-30            1690000            2480000
# 61                 15-8-15            1090000            1090000
# 62                 10-4-44            1690000            2480000
# 63                13-40-13            1090000            1090000
# 64                 12-8-40            1690000            2480000
# 65                15-10-30            1690000            2480000
# 66                 12-3-43            1690000            2480000
# 67                30-10-10            3120000            3120000
# 68                12-12-17             970000             970000
# 69                10-10-43            1690000            2480000
# 70                 15-5-15             900000            2300000
# 71                18-18-18            4200000            4200000
# 72                 3-11-38            1690000            2480000
# 73                 20-5-10            3120000            3120000
# 74                  30-6-6            3120000            3120000
# 75                  40-5-5            3120000            3120000
# 76                10-45-10            3200000            3200000
# 77                 10-5-40            1690000            2480000
# 78                18-10-18            1690000            2480000
# 79                10-30-10            1690000            2480000
# 80                  5-5-45            1690000            2480000
# 81                 19-6-20            5000000            5000000
# 82                  4-5-40            1690000            2480000
# 83                 15-50-5            3200000            3200000
# 84                 12-3-43            1690000            2480000
# 85                10-40-10            3200000            3200000
# 86                 5-10-40            1690000            2480000
# 87                19-19-19            3700000            3700000
# 88                 15-5-26            1690000            2480000
# 89                 17-4-30            1690000            2480000
# 90                40-10-10            1440000            1440000
# 91                 16-7-28            1690000            2480000
# 92                15-30-15            1700000            1700000
# 93                18-16-24            1690000            2480000
#
#     Exact_Price(Kg)               Sources sources_unique  \
# 53              NaN    https://torob.com/            NaN
# 54              NaN    https://torob.com/            NaN
# 55              NaN    https://torob.com/            NaN
# 56              NaN    https://torob.com/            NaN
# 57              NaN    https://torob.com/            NaN
# 58              NaN    https://torob.com/            NaN
# 59              NaN    https://torob.com/            NaN
# 60              NaN    https://torob.com/            NaN
# 61        1090000.0    https://torob.com/            NaN
# 62              NaN    https://torob.com/            NaN
# 63        1090000.0    https://torob.com/            NaN
# 64              NaN    https://torob.com/            NaN
# 65              NaN    https://torob.com/            NaN
# 66              NaN    https://torob.com/            NaN
# 67        3120000.0  https://agriplus.ir/            NaN
# 68         970000.0    https://torob.com/            NaN
# 69              NaN    https://torob.com/            NaN
# 70              NaN    https://torob.com/            NaN
# 71        4200000.0    https://torob.com/            NaN
# 72              NaN    https://torob.com/            NaN
# 73        3120000.0  https://agriplus.ir/            NaN
# 74        3120000.0  https://agriplus.ir/            NaN
# 75        3120000.0  https://agriplus.ir/            NaN
# 76        3200000.0    https://torob.com/            NaN
# 77              NaN    https://torob.com/            NaN
# 78              NaN    https://torob.com/            NaN
# 79              NaN    https://torob.com/            NaN
# 80              NaN    https://torob.com/            NaN
# 81        5000000.0    https://torob.com/            NaN
# 82              NaN    https://torob.com/            NaN
# 83        3200000.0    https://torob.com/            NaN
# 84              NaN    https://torob.com/            NaN
# 85        3200000.0    https://torob.com/            NaN
# 86              NaN    https://torob.com/            NaN
# 87        3700000.0    https://torob.com/            NaN
# 88              NaN    https://torob.com/            NaN
# 89              NaN    https://torob.com/            NaN
# 90        1440000.0    https://torob.com/            NaN
# 91              NaN    https://torob.com/            NaN
# 92        1700000.0    https://torob.com/            NaN
# 93              NaN    https://torob.com/            NaN
#
#    Group_of_fertilizer_unique
# 53                        NaN
# 54                        NaN
# 55                        NaN
# 56                        NaN
# 57                        NaN
# 58                        NaN
# 59                        NaN
# 60                        NaN
# 61                        NaN
# 62                        NaN
# 63                        NaN
# 64                        NaN
# 65                        NaN
# 66                        NaN
# 67                        NaN
# 68                        NaN
# 69                        NaN
# 70                        NaN
# 71                        NaN
# 72                        NaN
# 73                        NaN
# 74                        NaN
# 75                        NaN
# 76                        NaN
# 77                        NaN
# 78                        NaN
# 79                        NaN
# 80                        NaN
# 81                        NaN
# 82                        NaN
# 83                        NaN
# 84                        NaN
# 85                        NaN
# 86                        NaN
# 87                        NaN
# 88                        NaN
# 89                        NaN
# 90                        NaN
# 91                        NaN
# 92                        NaN
# 93                        NaN

# %%
allRawNpkRealNamesList = (
    raw_source_df_npk_filtered.iloc[:, 4]
    .astype(str)
    # Replace "-" with space
    .str.replace("-", " ", regex=False)
    # Replace +TE (case-insensitive) with " TE"
    .str.replace(r"\+TE", " TE", case=False, regex=True)
    # Replace +Ca (case-insensitive) with " Ca"
    .str.replace(r"\+Ca", " Ca", case=False, regex=True)
    # Collapse multiple spaces to one
    .str.replace(r"\s+", " ", regex=True)
    # Strip extra spaces at start/end
    .str.strip()
    .tolist()
)
allRawNpkRealNamesList
# Out:
# ['20 20 20',
#  '12 12 36',
#  '10 52 10',
#  '15 5 40',
#  '5 5 15',
#  '15 5 30',
#  '14 8 30',
#  '18 8 30',
#  '15 8 15',
#  '10 4 44',
#  '13 40 13',
#  '12 8 40',
#  '15 10 30',
#  '12 3 43',
#  '30 10 10',
#  '12 12 17',
#  '10 10 43',
#  '15 5 15',
#  '18 18 18',
#  '3 11 38',
#  '20 5 10',
#  '30 6 6',
#  '40 5 5',
#  '10 45 10',
#  '10 5 40',
#  '18 10 18',
#  '10 30 10',
#  '5 5 45',
#  '19 6 20',
#  '4 5 40',
#  '15 50 5',
#  '12 3 43',
#  '10 40 10',
#  '5 10 40',
#  '19 19 19',
#  '15 5 26',
#  '17 4 30',
#  '40 10 10',
#  '16 7 28',
#  '15 30 15',
#  '18 16 24']

# %%
filtered_df_npk
# Out:
#                                                    name category     price  \
# 910   کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فناو...      NaN     40000
# 966   کود تقویتی بمب انرژی رویش سبز NPKS حاوی نیتروژ...      NaN     55000
# 983                   کود کامل پودری GREEN SOUL سه بیست      NaN   1248000
# 994                           کود NPK سه بیست یک کیلویی      NaN    150000
# 996   کود npk کود کامل گیاهان آپارتمانی غنی شده تایم...      NaN    119000
# ...                                                 ...      ...       ...
# 8662               کود سه بیست (NPK 20 20 20) کوالی مکس  کود NPK  29000000
# 8674                       کود 10 52 10 NPK زیگلر آلمان  کود NPK   3960000
# 8676                           کود NPK 11 53 05 اینترمگ  کود NPK       NaN
# 8680                          کود 36 12 12 NPK فرمولایف  کود NPK  28175000
# 8684                              کود NPK 15 5 30 زیگلر  کود NPK  50030000
#
#       price_per_kg  amount_kg is_available  \
# 910   1.333333e+06       0.03         True
# 966   3.235294e+05       0.17         True
# 983   1.248000e+05      10.00         True
# 994   1.500000e+05       1.00         True
# 996   7.933333e+05       0.15         True
# ...            ...        ...          ...
# 8662  2.900000e+07       1.00         True
# 8674  3.960000e+06       1.00         True
# 8676  5.260000e+07       1.00        False
# 8680  2.817500e+07       1.00         True
# 8684  5.003000e+07       1.00         True
#
#                                        product_menu_url
# 910   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 966   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 983   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 994   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 996   https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# ...                                                 ...
# 8662                                                NaN
# 8674                                                NaN
# 8676                                                NaN
# 8680                                                NaN
# 8684                                                NaN
#
# [440 rows x 7 columns]

# %%
# rows = []

# # NPK to Dataframe
# for name in allRawNpkRealNamesList:
#     filtered = filtered_df_npk[filtered_df_npk['name'].str.contains(name, na=False)]
#     if filtered.empty:
#         continue  # skip if no matches
    
#     row = {
#         "code": raw_source_df_npk_filtered.iloc[allRawNpkRealNamesList.index(name),2], 
#         "name": name,
#         "med": filtered['price_per_kg'].mean(), 
#         "min": filtered['price_per_kg'].min(),
#         "max": filtered['price_per_kg'].max(),
#         "std": filtered['price_per_kg'].std(),
#         "listOfNames": filtered['name'].tolist(),
#         "listOfPrices": filtered['price_per_kg'].tolist(),
#     }
#     rows.append(row)

# # Convert list of dicts directly to a DataFrame
# result_df = pd.DataFrame(rows)

# print(result_df)

# %%
# import re
# import pandas as pd

# rows = []

# # Loop with index to avoid .index() inefficiency
# for idx, name in enumerate(allRawNpkRealNamesList):
#     # Normalize pattern for flexible matching:
#     # - Escape regex special chars
#     # - Allow spaces, slashes, or dashes between numbers
#     # - Remove "+TE" from matching requirements
#     pattern = re.escape(name)
#     pattern = pattern.replace(r"\ ", r"[\s\-\/]*")  # flexible spaces/dashes/slashes
#     pattern = re.sub(r"\+te$", r"(?:\+te)?", pattern, flags=re.IGNORECASE)  # optional +TE

#     # Filter again based on the specific code exist in the source list
#     filtered = filtered_df_npk[
#         filtered_df_npk['name']
#         .str.lower()
#         .str.contains(pattern, regex=True, na=False)
#     ]

    
#     # Delete the found row from the main dataframe
#     filtered_df_npk = [x for x in filtered_df_npk if x not in filtered]
    

#     if filtered.empty:
#         continue

#     row = {
#         "code": raw_source_df_npk_filtered.iloc[idx, 2],
#         "name": name,
#         "med": filtered['price_per_kg'].mean(),
#         "min": filtered['price_per_kg'].min(),
#         "max": filtered['price_per_kg'].max(),
#         "std": filtered['price_per_kg'].std(),
#         "listOfNames": filtered['name'].tolist(),
#         "listOfPrices": filtered['price_per_kg'].tolist(),
#     }
#     rows.append(row)

# # Final DataFrame
# result_df = pd.DataFrame(rows)
# print(result_df)

# %%
import re
import pandas as pd

rows = []

for idx, name in enumerate(allRawNpkRealNamesList):
    name_norm = name.lower().strip()

    # Flexible matching between numbers (any non-digit chars allowed)
    m = re.match(r'(\d+)\D+(\d+)\D+(\d+)', name_norm)
    if m:
        pattern = f"{m.group(1)}\\D*{m.group(2)}\\D*{m.group(3)}"
    else:
        pattern = re.escape(name_norm)

    # Make +TE / +Ca / +ME optional at the end (case-insensitive)
    pattern = re.sub(
        r'(\\\+\s*(?:te|ca|me))$',
        r'(?:\1)?',
        pattern,
        flags=re.IGNORECASE
    )

    filtered = filtered_df_npk[
        filtered_df_npk['name']
        .str.lower()
        .str.contains(pattern, regex=True, na=False)
    ]

    # Eliminate this row from the dataframe to have unique data
    filtered_df_npk = filtered_df_npk[~filtered_df_npk.isin(filtered)].dropna(how="all")



    if filtered.empty:
        continue

    row = {
        "code": raw_source_df_npk_filtered.iloc[idx, 2],
        "name": name,
        "med": filtered['price_per_kg'].mean(),
        "min": filtered['price_per_kg'].min(),
        "max": filtered['price_per_kg'].max(),
        "std": filtered['price_per_kg'].std(),
        "listOfNames": filtered['name'].tolist(),
        "listOfPrices": filtered['price_per_kg'].tolist(),
    }
    rows.append(row)

result_df = pd.DataFrame(rows)
print(result_df)
# Out:
#       code      name           med         min         max           std  \
# 0   17-111  20 20 20  1.105877e+06     32500.0  29000000.0  3.645248e+06
# 1   17-112  12 12 36  6.393968e+05    214000.0   1600000.0  4.508527e+05
# 2   17-113  10 52 10  1.619690e+06      2500.0  32000000.0  5.517335e+06
# 3   17-115    5 5 15  7.900000e+05    790000.0    790000.0           NaN
# 4   17-116   15 5 30  5.003000e+07  50030000.0  50030000.0           NaN
# 5   17-119   15 8 15  1.892000e+05    189200.0    189200.0           NaN
# 6   17-125  30 10 10  5.890000e+05    210000.0    980000.0  3.263393e+05
# 7   17-126  12 12 17  1.650000e+05    165000.0    165000.0           NaN
# 8   17-129  18 18 18  1.612593e+06    320000.0   4890000.0  2.189521e+06
# 9   17-131   20 5 10  1.351680e+05    135168.0    135168.0           NaN
# 10  17-133    40 5 5  3.425000e+05    342500.0    342500.0           NaN
# 11  17-139   19 6 20  4.890000e+06   4890000.0   4890000.0           NaN
# 12  17-143  10 40 10  2.425000e+05    242500.0    242500.0           NaN
# 13  17-144   5 10 40  2.000000e+05    200000.0    200000.0           NaN
# 14  17-150  15 30 15  3.825000e+05    345000.0    420000.0  5.303301e+04
#
#                                           listOfNames  \
# 0   [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 1   [کود 121236npk. زیگلر آلمان. فله ای, کود کامل ...
# 2   [کود کامل 10-52-10 تقویت ریشه دهی و گلدهی, کود...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# 5                                [ماکرو کامل 15/8/15]
# 6   [کود افزایش رشد نیتروژن بالا ( ازت بالا ) NPK ...
# 7                   [کود کامل121217همراه با ریز مغزی]
# 8   [کود هوس پلنت NPK 18-18-18 - کود ایتالیایی گری...
# 9    [کود هیومیک دار NPK 20-5-10 هیومولایف 5 کیلوگرم]
# 10               [كود کامل 40-5-5 هورتی گرو 2 کیلویی]
# 11                          [کود NPK 19 6 20 باواریا]
# 12  [کود مایع روتی فرت کود مدل NPK 10-40-10 حجم یک...
# 13  [کود مایع روتی فرت مدل NPK 5-10-40 حجم یک لیتر...
# 14  [کود کامل تقویتی فسفر بالای ریشه زایی فراگین م...
#
#                                          listOfPrices
# 0   [1333333.3333333335, 416666.6666666667, 295000...
# 1   [940000.0, 1076923.076923077, 860000.0, 160000...
# 2   [750000.0, 983333.3333333334, 300000.0, 960000...
# 3                                          [790000.0]
# 4                                        [50030000.0]
# 5                                          [189200.0]
# 6            [980000.0, 476000.0, 690000.0, 210000.0]
# 7                                          [165000.0]
# 8   [626086.9565217391, 614285.7142857142, 320000....
# 9                                          [135168.0]
# 10                                         [342500.0]
# 11                                        [4890000.0]
# 12                                         [242500.0]
# 13                                         [200000.0]
# 14                               [420000.0, 345000.0]

# %%
npk_excluded_raw_source = raw_source_df[raw_source_df["input_code"] != 17]
npk_excluded_raw_source
# Out:
#      sub_input_code  input_code Name_of_fertilizer Group_of_fertilizer  \
# 0               113          11             11-113  کود نیتروژن (ازته)
# 1               114          11             11-114  کود نیتروژن (ازته)
# 2               115          11             11-115  کود نیتروژن (ازته)
# 3               116          11             11-116  کود نیتروژن (ازته)
# 4               117          11             11-117  کود نیتروژن (ازته)
# ..              ...         ...                ...                 ...
# 190             111          11             11-111  کود نیتروژن (ازته)
# 191             117          21             21-117         کود های آلی
# 192             144          19             19-144             ریزمغذی
# 193             115          21             21-115         کود های آلی
# 194             112          20             20-112        کود های دامی
#
#     Real_Name_of_fertilizer  Minimum_Price(Kg)  Maximum_Price(Kg)  \
# 0            نیترات آمونیوم             640000             640000
# 1               اسید نیتریک             640000             640000
# 2            سولفات آمونیوم             210000             100000
# 3       اوره با پوشش گوگردی             144000             144000
# 4              اوره سولفاتی             355000             355000
# ..                      ...                ...                ...
# 190                    اوره              25000             600000
# 191                 کود سبز             580000            1550000
# 192                 سیلیکون            1800000            3900000
# 193                  کمپوست              30000              30000
# 194                    مرغی              50000             100000
#
#      Exact_Price(Kg)                    Sources  \
# 0           640000.0                  torob.com
# 1           640000.0                  torob.com
# 2           155000.0   https://www.bbk-iran.com
# 3           144000.0      https://digikoud.com/
# 4           355000.0       https://digikoud.com
# ..               ...                        ...
# 190          42500.0  https://www.bbk-iran.com/
# 191              NaN    https://royalkesht.com/
# 192              NaN   https://sepahankesht.com
# 193              NaN    https://royalkesht.com/
# 194              NaN         https://torob.com/
#
#                       sources_unique Group_of_fertilizer_unique
# 0                          torob.com                  کود پتاسه
# 1           https://www.bbk-iran.com                  کود کلسیم
# 2              https://digikoud.com/                 کود منیزیم
# 3               https://digikoud.com                 کود گوگردی
# 4    https://basalam.com/search/list       کود های کامل (N-P-K)
# ..                               ...                        ...
# 190        https://www.bbk-iran.com/         کود نیتروژن (ازته)
# 191                              NaN                        NaN
# 192                              NaN                        NaN
# 193                              NaN                        NaN
# 194                              NaN                        NaN
#
# [154 rows x 11 columns]

# %%
npk_excluded_raw_source.iloc[:,4].tolist()
cleaned_col = npk_excluded_raw_source.iloc[:, 4].str.replace("+", " ", regex=False).str.replace("\xad\u200c", " ", regex=False).str.replace(")"," ").replace("("," ").replace("های"," ").replace("کودهای","کود").replace("باکتریهای","باکتری").replace("...)"," ").replace("+TE", " TE").replace("+Ca"," Ca").replace("اسیدهای","اسید")
npk_excluded_raw_source.iloc[:,4] = cleaned_col
npk_excluded_raw_source
# Out:
#      sub_input_code  input_code Name_of_fertilizer Group_of_fertilizer  \
# 0               113          11             11-113  کود نیتروژن (ازته)
# 1               114          11             11-114  کود نیتروژن (ازته)
# 2               115          11             11-115  کود نیتروژن (ازته)
# 3               116          11             11-116  کود نیتروژن (ازته)
# 4               117          11             11-117  کود نیتروژن (ازته)
# ..              ...         ...                ...                 ...
# 190             111          11             11-111  کود نیتروژن (ازته)
# 191             117          21             21-117         کود های آلی
# 192             144          19             19-144             ریزمغذی
# 193             115          21             21-115         کود های آلی
# 194             112          20             20-112        کود های دامی
#
#     Real_Name_of_fertilizer  Minimum_Price(Kg)  Maximum_Price(Kg)  \
# 0            نیترات آمونیوم             640000             640000
# 1               اسید نیتریک             640000             640000
# 2            سولفات آمونیوم             210000             100000
# 3       اوره با پوشش گوگردی             144000             144000
# 4              اوره سولفاتی             355000             355000
# ..                      ...                ...                ...
# 190                    اوره              25000             600000
# 191                 کود سبز             580000            1550000
# 192                 سیلیکون            1800000            3900000
# 193                  کمپوست              30000              30000
# 194                    مرغی              50000             100000
#
#      Exact_Price(Kg)                    Sources  \
# 0           640000.0                  torob.com
# 1           640000.0                  torob.com
# 2           155000.0   https://www.bbk-iran.com
# 3           144000.0      https://digikoud.com/
# 4           355000.0       https://digikoud.com
# ..               ...                        ...
# 190          42500.0  https://www.bbk-iran.com/
# 191              NaN    https://royalkesht.com/
# 192              NaN   https://sepahankesht.com
# 193              NaN    https://royalkesht.com/
# 194              NaN         https://torob.com/
#
#                       sources_unique Group_of_fertilizer_unique
# 0                          torob.com                  کود پتاسه
# 1           https://www.bbk-iran.com                  کود کلسیم
# 2              https://digikoud.com/                 کود منیزیم
# 3               https://digikoud.com                 کود گوگردی
# 4    https://basalam.com/search/list       کود های کامل (N-P-K)
# ..                               ...                        ...
# 190        https://www.bbk-iran.com/         کود نیتروژن (ازته)
# 191                              NaN                        NaN
# 192                              NaN                        NaN
# 193                              NaN                        NaN
# 194                              NaN                        NaN
#
# [154 rows x 11 columns]

# %% [markdown]
# Other fertilizers

# %%
# # Others to Dataframe
# for counter in range(len(npk_excluded_raw_source.iloc[:,4].tolist())):
#     name = npk_excluded_raw_source.iloc[:,4].tolist()[counter]
#     filtered = df[df['name'].str.contains(re.escape(name), na=False, case=False)]
#     if filtered.empty:
#         continue  # skip if no matches
    
#     row = {
#         "code": npk_excluded_raw_source.iloc[counter,2], 
#         "name": name,
#         "med": filtered['price_per_kg'].mean(), 
#         "min": filtered['price_per_kg'].min(),
#         "max": filtered['price_per_kg'].max(),
#         "std": filtered['price_per_kg'].std(),
#         "listOfNames": filtered['name'].tolist(),
#         "listOfPrices": filtered['price_per_kg'].tolist(),
#     }
#     rows.append(row)

# # Convert list of dicts directly to a DataFrame
# result_df = pd.DataFrame(rows)

# print(result_df)

# %%
# Find "سیلیکات پتاسیم"

def normalize_text(s):
    if pd.isna(s):
        return ""
    # Replace Arabic forms with Persian
    s = s.replace("ي", "ی").replace("ك", "ک")
    # Remove zero-width and non-breaking spaces
    s = re.sub(r"[\u200c\u200f\u00a0]", "", s)
    return s

df["name_clean"] = df["name"].apply(normalize_text)

# Now search
df[df["name_clean"].str.contains("سیلیکات", na=False)]
# Out:
#                                                    name category    price  \
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...      NaN   420000
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...      NaN   175000
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...      NaN   480000
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...      NaN   255600
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس      NaN   385000
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری      NaN   400000
# 2620                         کود سیلیکات کلسیم یا کلسیل      NaN   390000
# 2913                            کود سیلیکات پتاسیم زایز      NaN  1175000
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل      NaN   400000
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل      NaN  3700000
# 4081               کود مایعسیلیکات پتاسیم ورساد اسپانیا      NaN   460000
# 4838                        کود سیلیکات پتاسیم اگرولایو      NaN   345000
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...      NaN  1800000
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع ...      NaN   500000
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان      NaN   250000
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک      NaN   580000
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...      NaN  1500000
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر      NaN   735000
# 7780                    سیلیکات پتاسیم سیترال (1 لیتری)      NaN   350000
# 7784                    سیلیکات پتاسیم پروسیل (1 لیتری)      NaN   500000
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان 5 لیتری      NaN  1180000
# 8309                             سیلیکات پتاسیم(5لیتری)      NaN  1200000
#
#       price_per_kg  amount_kg is_available  \
# 1286      420000.0        1.0         True
# 1375      175000.0        1.0         True
# 1385      480000.0        1.0         True
# 1899      255600.0        1.0         True
# 2120      385000.0        1.0         True
# 2304      400000.0        1.0         True
# 2620      390000.0        1.0         True
# 2913     1175000.0        1.0         True
# 3089      400000.0        1.0         True
# 3091       18500.0      200.0         True
# 4081      460000.0        1.0         True
# 4838      345000.0        1.0         True
# 5024      360000.0        5.0         True
# 5032      500000.0        1.0         True
# 5471      250000.0        1.0         True
# 6424      580000.0        1.0         True
# 6511      300000.0        5.0         True
# 7354      147000.0        5.0         True
# 7780      350000.0        1.0         True
# 7784      500000.0        1.0         True
# 8235      236000.0        5.0         True
# 8309      240000.0        5.0         True
#
#                                        product_menu_url  \
# 1286  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1375  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1385  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1899  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2120  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2304  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2620  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2913  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 3089  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 3091  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 4081  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 4838  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5024  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5032  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5471  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 6424  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 6511  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 7354                                                NaN
# 7780                                                NaN
# 7784                                                NaN
# 8235                                                NaN
# 8309                                                NaN
#
#                                              name_clean
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری
# 2620                         کود سیلیکات کلسیم یا کلسیل
# 2913                            کود سیلیکات پتاسیم زایز
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل
# 4081               کود مایعسیلیکات پتاسیم ورساد اسپانیا
# 4838                        کود سیلیکات پتاسیم اگرولایو
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع ...
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر
# 7780                    سیلیکات پتاسیم سیترال (1 لیتری)
# 7784                    سیلیکات پتاسیم پروسیل (1 لیتری)
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان 5 لیتری
# 8309                             سیلیکات پتاسیم(5لیتری)

# %%
df["name"].tolist()
# Out:
# ['اسید هیومیک پودری 50 گرمی و ( 10 کیلویی فرومیتو )',
#  'کود سولفات پتاسیم فلورامی 100 گرمی (potassium Sulfate )',
#  'کود هیومیک اسید نیکوبذر',
#  'کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فناور سبز',
#  'کود مایع مخصوص گل بابا آدم برند تایمکس حجم 150 میلی لیتر',
#  'کود هیومیک اسید مایع تتاکو HUMORE بسته یک لیتری',
#  'روغن ولک براق کننده گل و گیاهان آپارتمانی',
#  'کود انپیکا 202020 . سه بیست پودری',
#  'کود کلسیم',
#  'کود سولفات پتاسیم 51-0-0 زیگلر آلمان (50 گرم کود خالص)',
#  'کود جلبک دریایی مارمارین اصل ( 50 سی سی ) - تولید کمپانی IFTC آمریکا',
#  'کود مخصوص کاکتوس و ساکولنت 38 11 3نیکوبذر',
#  'کود آمینو اسید اسید آمینه. ضد تنش گیاه',
#  'کود اسید آمینه 65 درصد - ایزابیون سوئیس 50 سی سی',
#  'بیورادیکانت کود ریشه زای قوی محصولی از فیوچراکو اسپانیا بسته بندی نیم لیتری',
#  'کود همه کاره ارگانیک ویتامینه گیاهان (سوپر) ویژه ی گیاهان آپارتمانی و زینتی',
#  'کود کلسیم +بور تتاکو مناسب گلدان و باغچه وزن 120 گرم',
#  'کود مونو پتاسیم فسفات گرین پیک مدل Mono Potassium Phosphate 1000 وزن یک کیلوگرم',
#  'کود بنفشه آفریقایی محصول Pokon هلند (30 سی سی)',
#  'کود تقویتی بمب انرژی رویش سبز NPKS حاوی نیتروژن فسفر و پتاسیم.120 میلی لیتر',
#  'کود سفید شکری (سولفات آمونیوم) فلونیا حجم یک کیلوگرم',
#  'کود سه 10 پودر 70 گرمی حاصلخیز با فناوری XGREEN',
#  'کود مایع آلی حاوی هیومیک اسید GREEN SOUL پنج لیتری',
#  'کود کامل پودری GREEN SOUL سه بیست',
#  'کود NPK سه بیست یک کیلویی',
#  'کود npk کود کامل گیاهان آپارتمانی غنی شده تایمکس ( 150 میلی لیتر )',
#  'کود گلدهی 10-52-10 باواریا آلمان (50گرم کود خالص)- مخصوص پرحجم کردن ریشه و تحریک به گلدهی',
#  'کود مونو پتاسیم فسفات تولید زیگلر آلمان (بسته 50 گرمی)',
#  'مجموعه کود مولتی برگدهی وNPK و هیومیک و کود آهن مدل Danesh PK حجم 120 بسته 4تایی',
#  'کود مونو آمونیوم فسفات تتاکو مناسب گیاهان خانگی وزن 120 گرم',
#  'کود سه بیست 20 20 ( 50 گرم کود خالص) برند معتبر باواریا آلمان - کود کامل npk',
#  'کود سه بیست 20 20 (بسته 250 گرمی) برند معتبر باواریا (Bavaria) آلمان',
#  'کود انپیکا 121236. پتاس بالا .مخصوص پاجوش دهی و گلدهی',
#  'کود انپیکا 105210 . فسفر بالا. ریشه زا',
#  'کود پیلینوس (بور + جلب کننده زنبور) 250 سی سی',
#  'کود جلبک دریایی بارسلوس ضد تنش و عامل پهن شدن برگ های پتوس',
#  'کود گلدهی 10-52-10 باواریا آلمان (250 گرم کود خالص)- مخصوص تحریک به گلدهی',
#  'آشواگاندا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'کود NPK 20-20-20 تتاکو مناسب گلدان و باغچه وزن 120 گرم',
#  'کود تقویتی 105210 بارسلوس 50 گرمی',
#  'کود پتاس 121236 مناسب پاجوش زایی و گلدهی',
#  'کود گلدهی پتاس بالا 121236 نیکوبذر',
#  'کود زاموفیلیا تایمکس حجم 150میلی لیتر کود زامیفولیا',
#  'کود ریشه زا بیورادیکانت نیم لیتری',
#  'کود جلبک دریایی آمریکایی مایع + هورمون رشد',
#  'گیاه درمنه ترکی با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'کود کامل گیاهان 10 ایکس شوک مایع اصل آمریکایی یک لیتری (پس کرایه)',
#  'کود آمینو اسیدکود ویتامینه وضد تنشامینو اسید',
#  'کود مایع انرژی ایکس گرین (آمینو اسید) 250 سی سی',
#  'کود کلات آهن 60گرمی- مناسب جوانه زنی وافزایش سبزینگی گیاهان-کود آهن پودری-کود گیاهان آپارتمانی-کود کامل گیاه-گلدونه',
#  'کود آمینواسید شوک 80 درصد اصل آمریکایی یک لیتری (پس کرایه)',
#  'کود مایع آهن افرا مخصول گل های آپارتمانی',
#  'کود جلبک دریایی اسپانیائی',
#  'آگلونما رد بیوتی Aglaonema red beauty هزینه ارسال بصورت پس کرایه و بعهده مشتری می باشد',
#  'گل منحصربفرد آلوکازیا رد سکرت که از فضا اومده هزینه ارسال بصورت پس کرایه و بعهده مشتری می باشد',
#  'کود سوپر پتاسیم هیومات',
#  'کود گیاه بلک گلد وزن 800 گرم',
#  'کود تقویتی مخصوص درخت کاج هپی پلنت مدل HP459 حجم 120 میلی لیتر',
#  'کود مایع محرک رشد کروتون مدل Super power حجم 120 میلی لیتر بسته دو عددی',
#  'کود مخصوص برگ دهی هپی پلنت مدل HP502 حجم 120 میلی لیتر',
#  'کود سولفات روی هپی پلنت مدل SZN وزن 50 گرم',
#  'کود تقویتی مخصوص گل داوودی هپی پلنت مدل HP410 حجم 120 میلی لیتر',
#  'کود نیترات کلسیم هپی پلنت مدل CAN وزن 100 گرم',
#  'کود مایع کامل سانسوریا گلبان کود مدل G حجم 220 میلی لیتر',
#  'کود مایع کامل غنی شده محرک برگ دهی گیاهان مدل DaneshPlus حجم 120 میلی لیتر',
#  'کود مایع ارگانیک غنی شده محرک رشد رویشی مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه گل مرجان مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه گیلاس اورشلیم مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل مکمل رشد گیاه حسن یوسف مدل Super Power 13 حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه گل شیپوری مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه گلهای شاخه بریده مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع مکمل رشد فیلودندرون مدل Super Power 01 حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه زاموفیلیا بلک مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه سبزی کاری مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود مایع کامل ارگانیک غنی شده ویژه فیکوس آفریقایی مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود کامل دراسنا مدل A31 حجم 120 میلی لیتر',
#  'کود نخل لیکوالا مدل A63 حجم 120 میلی لیتر',
#  'کود کامل بنجامین فیکوس بلک ابلق و آمستل مدل A33 حجم 120 میلی لیتر',
#  'کود کامل آدنیوم مدل Adnium حجم 120 میلی لیتر',
#  'کود پاچیرا مدل A70 حجم 120 میلی لیتر',
#  'کود کامل لیراتا فیکوس افریقایی مدل A27 حجم 120 میلی لیتر',
#  'کود کامل فیلودندرون گوش گرگی مدل Filn حجم 120 میلی لیتر',
#  'کود مایع درخت لیمو کد Pak حجم 120 میلی لیتر بسته 8 عددی',
#  'کود سه مرحله ای پتوس مدل ABC2022 حجم 120 میلی لیتر بسته سه عددی',
#  'کود پتوس و اسید آمینه و آهن و مولتی کود کد A01 حجم 120 میلی لیتر بسته 4 عددی',
#  'کود مایع مولتی کود مخصوص گل های آپارتمانی مدل Fast growth حجم کل 300 میلی لیتر بسته سه عددی',
#  'کود مایع زاموفیلیا و پتوس و سانسوریا و هیومیک مدل A حجم 120 میلی لیتر بسته 8 عددی',
#  'کود مایع قطره چکانی گلدهی گیاهان خانگی گلبان کود مدل Fast growth حجم 300 میلی لیتر بسته سه عددی',
#  'کود تقویتی مخصوص مورد زینتی هپی پلنت مدل HP447 حجم 120 میلی لیتر',
#  'کود مایع محرک رشد شامادورا مدل Super powerحجم 120 میلی لیتر بسته دو عددی',
#  'کود مایع گل دهی گیاهانو کلات آهن و سه بیست و هیومیک مدل A حجم 120 میلی لیتر بسته 8 عددی',
#  'کود مایع محرک رشد برگ دهی مدل Mpower حجم 120 میلی لیتر بسته دو عددی',
#  'کود مایع محرک رشد حسن یوسف مدل Mpower حجم 120 میلی لیتر بسته سه عددی',
#  'کود مایع محرک رشد انواع سرخس مدل Mpower حجم 120 میلی لیتر بسته دو عددی',
#  'کود مایع زاموفیلیا گلبان کود مدل Fast growth حجم 100 میلی لیتر بسته سه عددی',
#  'کود مایع مخصوص گیاهان برگی هپی پلنت مدل HP26 حجم 420 میلی لیتر',
#  'کود مایع محرک رشد فیکوس مدل Spower حجم 120 میلی لیتر بسته سه عددی',
#  'کود مایع مرکب مدل 15 حجم 120 میلی لیتر',
#  'کود کامل مایع پتوس مدل A33 حجم 120 میلی لیتر بسته دو عددی',
#  'کود مایع محرک رشد گیاه گندمی مدل Super powerحجم 120 میلی لیتر بسته دو عددی',
#  'کود تقویتی مخصوص درخت سیب هپی پلنت مدل HP436 حجم 120 میلی لیتر',
#  'کود مایع مرکب زاموفیلیا مدل ZD7 حجم 120 میلی متر بسته 3 عددی',
#  'کود مایع دیفن باخیا و مولتی کود و کود برگ دهی و هیومیک مدل A حجم 120 میلی لیتر بسته 8 عددی',
#  'کود تقویتی بنسای هپی پلنت مدل HP35 حجم 120 میلی لیتر',
#  'کود کامل مایع مخصوص گل مرجان مدل A33 حجم 120 میلی لیتر بسته 8 عددی',
#  'کود مایع مرکب مدل Bahar34 حجم 120 میلی لیتر',
#  'کود مایع محرک رشد گیاه درسنا مدل Super powerحجم 120 میلی لیتر بسته دو عددی',
#  'کود تقویتی آهن کلاته مایع هپی پلنت مدل EDDHA حجم 60 میلی لیتر',
#  'کود تقویتی مخصوص درخت خرمالو هپی پلنت مدل HP428 حجم 120 میلی لیتر',
#  'کود تقویتی آگلونما هپی پلنت مدل HP55 حجم 120 میلی لیتر',
#  'کود تقویتی مخصوص حسن یوسف هپی پلنت مدل HP33 حجم 120 میلی لیتر',
#  'کود تقویتی عناصر ریز مغذی میکرو مایع هپی پلنت مدل میکرومیکس حجم 60 میلی لیتر',
#  'کود مایع آلوئه ورا کد Pak حجم 120 میلی لیتر بسته 8 عددی',
#  'کود مایع اسپری مدل 21 حجم 100 میلی لیتر',
#  'کود سه مرحله ای سانسوریا مدل ABC2022 حجم 120 میلی لیتر بسته سه عددی',
#  'کود مایع محرک رشد مدل 13 حجم 120 میلی لیتر بسته دو عددی',
#  'کود ریشه زایی و سه بیست و هیومیک و آهن کد A08حجم 120 میلی لیتر بسته 4 عددی',
#  'کود مایع کامل ارگانیک غنی شده ویژه سرو پژیا مدل OrgaFerti حجم 120 میلی لیتر',
#  'کود درسنا و سه بیست و هیومیک و آهن کد A05 حجم 120 میلی لیتر بسته 4 عددی',
#  'کود مایع محرک رشد آلوئه ورا مدل Mpower حجم 120 میلی لیتر بسته سه عددی',
#  'کود مایع محرک رشد دیوار سبز مدل Mpower حجم 250 میلی لیتر بسته دو عددی',
#  'کود مایع NPK سه بیست کد Pak حجم 120 میلی لیتر بسته 8 عددی',
#  'کود شمعدانی و سه بیست و هیومیک و آهن کد A09حجم 120 میلی لیتر بسته 4 عددی',
#  'کود مایع مرکب برگ انجیری گلبان کود مدل GLBK حجم 440 میلی لیتر بسته دو عددی',
#  'کود مایع کامل مکمل رشد گیاه اسطوخدوس مدل Super Power 01 حجم 120 میلی لیتر',
#  'کود مایع قطره چکانی دیفن باخیا گلبان کود مدل Fast growth حجم 300 میلی لیتر بسته سه عددی',
#  'کود مایع محرک رشد پتوس طلایی مدل Mpower حجم 120 میلی لیتر بسته سه عددی',
#  'کود مایع مرکب ریشه زایی گیاهان آپارتمانی مدل Bahar25 حجم 120 میلی لیتر',
#  'کود تقویتی کالسیو آلفردو اینستا اسپانیا حاوی کلسیم و اسید آمینه یک لیتری',
#  'کود تریو پلاس ارونتیکا اسپانیا FMZ حاوی آهن  روی و منگنز',
#  'کود ریشه زای بیو رادیکانت فیوچرکو اسپانیا یک لیتری',
#  'کود رشد 10.52.10 فسفر بالا پودری با حلالیت بالا 100 گرمی ( هزینه ارسال پسکرایه)',
#  'کود آهن فیکو مخصوص درختان مثمر و گلدان و گیاهان آپارتمانی و خانگی',
#  'کاکتوس فروتیغ طلائی بسیار باکیفیت و کلکسیونی مدل کاکتوسچی',
#  'کود آلی وتقویت کننده ورم کستینگچهار گالنی(پس کرایه)',
#  'کود کاکتوس و ساکولنت ملکه محصول آلمان(وزن80گرم)',
#  'کود 10 52 10 وانوما با عناصر ماکرو و میکرو ده کیلویی',
#  'کود مایع زاموفیلیا تایمکس - کود مایع 30 میلی لیتر',
#  'کود مایع بونسای گرین گروس- پک سه عددی- هر کدام 90 میلی لیتر',
#  'کود نونامیک K-CU فسفیت پتاسیم مایع(پس کرایه)',
#  'کود NPK سه بیست 20/20/20+TE',
#  'کود گیاهان اپارتمانی (پس کرایه)',
#  'کود هیومیک اسید مایع جنریت پنج لیتری محصول آمریکا 95 درصد خلوص',
#  'کود مایع آهن نانو 11درصد پنج لیتری جنریت اصلی محصول آمریکا',
#  'کود مایع آمینو اسید جنریت آمریکا پنج لیتری',
#  'کود مایع کلسیم 27 درصد جنریت پنج لیتری اصلی محصول آمریکا',
#  'کود مایع فروت ست جنریت آمریکا یک لیتری',
#  'کود مایع فسفیت پتاسیم جنریت آمریکا پنج لیتری',
#  'کود کلسیم شوک یک لیتری (پس کرایه)',
#  'کود هیبرید 10 گرمی فیدینگ مناسب گلدهی',
#  'کود رشد 10 گرمی فیدینگ مناسب برای مرحله رشد',
#  'کود کامل 10-52-10 تقویت ریشه دهی و گلدهی',
#  'کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سرما (پس کرایه)',
#  'کود(جلبک دریایی)دکتر یشیل',
#  'کود تقویتی فیدینگ 10 گرمی',
#  'کود اسید آمینه بهاران پودری',
#  'کود تقویتی و محرک رشد اکتیواتور 250 میلی لیتر',
#  'کود NPK10 10 25 TE',
#  'کود NPK20 20 20',
#  'کود کلسیم ملکه',
#  'کود تقویتی گیاهان آپارتمانی (مولتی کود)',
#  'کود تقویتی ویژه نهالباغ و گیاهان زینتی 250سی سی جنرال پاور حاوی محرک رشد غنی شده با هیومیک اسید',
#  'کود ورمی کمپوست ورمی کمپوست یک کیلو',
#  'کود پتاسیم (40گرمی)(RICO)',
#  'ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'کود فسفیت پتاسیم IFTC اردن',
#  'کود مخصوص گلدهی زعفران شوک پلاس یک لیتری',
#  'کود مس 99درصد شوک پلاس امریکایی یک لیتری',
#  'کود جلبک دریایی مایع با کیفیت قوی اورجینال ترکیه جلبک دریایی مایع',
#  'کود آپارتمانی گرین مکس 1 (پس کرایه)',
#  'کود گارد 1 فلوریش (پس کرایه)',
#  'کود جنرال هیدروپونیک باشلود 250 میلی',
#  'کود گروتک کربومکس پودری بسته 500 گرم',
#  'کود پتاس بالا و هیومیک اسید ارسال پس کرایه',
#  'میکس سه تایی ( کودهای سه 20  محرک گلدهی و محرک ریشه زایی )',
#  'کود پتاس بالای K66 جنریت یک لیتری66درصدپتاس محصول ایالات متحده',
#  'کود مایع اسید هیومیک95درصد یک لیتری جنریت محصول ایالات متحده',
#  'کود کلسیم مایع 27درصد جنریت گالن پنج لیتری گالن اصلی',
#  'کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم یک لیتر( پس کرایه )',
#  'کود روی یاراویتا-پس کرایه',
#  'کود کلات منگنز یاراویتا-پس کرایه',
#  'کود بذرمال روی یاراویتا-پس کرایه',
#  'کود کلسیم و فسفر یاراویتا-پس کرایه',
#  'پک کود هیدروپونیک کریستا',
#  'کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس کرایه)',
#  'کود آهن بمب (پس کرایه)',
#  'کود پتاس بالا نیورایز 30-5-15 (پس کرایه)',
#  'کود آهن ( کلات آهن )',
#  'کود 36-12 -12 ( محرک گلدهی )',
#  'میکس دوتایی ( کود آهن و کود 10-52-10 )',
#  'کود ماکرو کامل غنی شده با هیومیک اسید 10-10-10',
#  'کود مخصوص آنتوریوم',
#  'کود فسفر پتاسیم لرد رکورد یک لیتری',
#  'کود کامل مایع ایکس گرین فینیش250سی سی25-25-25',
#  'کود هربان 150',
#  'پک سه عددی پتوس سبز و زعفرانی و نئون سایز 10',
#  'کود اسید هیومیک پلنت استار (ارسال به صورت پس کرایه )',
#  'کود مرغی غنی شده گرانول سارک کود',
#  'کود کامل گیاهی سرشار از انواع مواد مغزی و نایاب',
#  'کود سدیم',
#  'کود گیاهی طبیعی خالص',
#  'کود کلات روی 15 درصد ترکیه ای مخصوص محلول پاشی بسته بندی یک کیلوگرمی',
#  'کود هیدروپونیک مایع مخصوص انواع ملون کد LMe1000',
#  'کود هیدروپونیک مایع مخصوص میوه دهی کد LP100',
#  'کود هیدروپونیک جامد مخصوص گوجه فرنگی و صیفی جات کد T100',
#  'کود هیدروپونیک جامد مخصوص گلدهی کد B100',
#  'کود هیدروپونیک مایع مخصوص مرحله رویشی کد LG100',
#  'کود هیدروپونیک مایع هوگلند کد LH100',
#  'کود هیدروپونیک جامد مخصوص دوره رویشی کد G100',
#  'کلسیم 27 درصد مایع نانو کود',
#  'کود پودری کامل NPK 20-20-20 + TE(یک کیلویی)',
#  'کود پتاس بالا یا121236 رشد انفجاری گیاهان',
#  'کود سه بیست 202020 وارداتی در بسته بندی صد گرمی',
#  'هورمون گلدهی کود بلوم بوستر محرک شکوفه کینگ مکس مکزیکی',
#  'کود آلی نیتروژنه و پتاسیم بسته 20 گرمی',
#  'کود اسید آمینه نوافول نواگرو ایتالیا 60 سی سی (آمینو اسید و محرک رشد) ( novafol )',
#  'کود ماکرو( NPK 10-10-10) غنی شده با جلبک دریایی  اسید امینه و ماده الی',
#  'فروش کود کلاته میکروکامل خضرا پسکرایه',
#  'کود های آپارتمانی',
#  'کود برگ دهی پلاس10 10 30 نیکوبذر(گرم بالا)',
#  'کود زاموفیلیا - کود کامل و تخصصی (60 گرم کو خالص)',
#  'کود سولفات منیزیم فلورامی 50 گرمی (Magnesium sulfate)',
#  'کود کال مگ (اکتی کلسیم-منیزیم) نواگرو ایتالیا 60 سی سی ( novagro)',
#  'کود امکس بیو 20 گلد 50 میلی لیتر مصرف خانگی',
#  'گیاه سداب با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه پرسیاوشان بار امسالی و تازه(50گرمی )',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'گیاه گل بنفشه با کیفیت عالی بار امسالی و تازه(50گرم)',
#  'آلوئه ورا با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه مرزنجوش پودر شده با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه خرفه با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گیاه درمنه ترکی بار امسالی و تازه(50گرمی )',
#  'گیاه گزنه با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه جعفری بار امسالی و تازه (250 گرمی)',
#  'گیاه خرفه با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه مرزنجوش با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه خار شتر پودر شده بار امسالی و تازه(100گرمی )',
#  'گل مینا با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه خارخاسک با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'ریشه آنغوزه با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'گیاه نعناع دشتی با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه کاسنی با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گل قاصدک بار امسالی و تازه(150گرمی)',
#  'گیاه چای ترش بار امسالی و تازه(100گرم)',
#  'گل بومادارن با کیفیت عالی بار امسالی و تازه(50 گرمی )',
#  'گیاه درمنه ترکی با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه دم اسب با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'پودر ریشه چله داغی ( آدمک)(اصل و کاملا خالص)',
#  'ریشه شیرین بیان (بدون پوست) بار امسالی و تازه(150گرمی)',
#  'ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'برگ جینکو با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'گل بابونه با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'پونه با کیفیت عالی بار امسالی و تازه(50 گرمی )',
#  'گیاه خار مریم با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'ریشه آنغوزه با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'استویا با کیفیت عالی بار امسالی و تازه(250گرمی)',
#  'باباآدم با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه آلوئه ورا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'الدر بری کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گیاه آلوئه ورا با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گل مینا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'پوست اسفرزه با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'باباآدم با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه گزنه با کیفیت عالی بار امسالی و تازه(50گرمی )',
#  'ریشه کاسنی با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'افسنطین با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'گیاه رازک با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گل بابونه با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گل انار با کیفیت عالی بار امسالی و تازه(150 گرمی)',
#  'افتیمون با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل اسطوخودوس (هندی) با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'بولاغ اوتی با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گل بید مشک با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'غنچه گل محمدی با کیفیت عالی بار امسالی و تازه(200گرمی )',
#  'گیاه گزنه با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'بارهنگ با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل همیشه بهاربا کیفیت عالی بار امسالی و تازه(150گرمی )',
#  'بارهنگ با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'بارهنگ با کیفیت عالی بار امسالی و تازه(150 گرمی )',
#  'برگ خرگوشک با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'آلوئه ورا با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گیاه گزنه با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'ریشه خولنجان با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گل قاصدک با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'الدر بری با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گل اسطوخودوس ایرانی با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه شاهتره با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گل اسطوخودوس ایرانی با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'برگ سنا با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(200 گرمی )',
#  'گیاه رازک با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'فروش الدر بری (آقطی سیاه) با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه آلوئه ورا با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(51گرمی)',
#  'گیاه مورد با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'غنچه گل محمدی با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'کود 10-52-10(مخصوص ریشه)100 گرمی',
#  'کود 36-12-12 (پتاس بالا) 200 گرمی',
#  'کود فروت ست مایع یک لیتری',
#  'کود 20-20-20 (سه بیست) 500 گرمی',
#  'کود فسفره گیاهان اپارتمانی پلاتو مدل 10-54-10 وزن 100 گرم',
#  'کود رویشی دراگون فایر cc250',
#  'کود زایشی کریستا 120 سی سی',
#  'کود NPK 20 20 20 ده کیلویی گهرزا',
#  'کود فسفر بالا10.52.10 NPK پودری تایمکس',
#  'کود محرک رشد ارگانیک(جلبک دریایی) کیمیا کود گواشیر',
#  'کود اوره گرین پیک مدل UREA 1000 وزن یک کیلوگرم',
#  'کود نیترات کلسیم گرین پیک مدل CALSIUM NITRATE 1000 وزن یک کیلوگرم',
#  'کود کامل زایشی و رویشی گرین پیک مدل NPK 15-05-30 وزن یک کیلوگرم',
#  'بسته پنج تایی کود همه کاره ارگانیک ویتامینه گیاهان ویژه ی نهال باغات صیفی و سبزیجات',
#  'بسته پنج تایی کود همه کاره ارگانیک ویتامینه گیاهان ویژه ی گیاهان آپارتمانی و زینتی',
#  'کود ریشه زایی',
#  'کود کامل 20-20-20',
#  'کود کلات آهن افزایش سبزینگی گیلدا مدل 6 درصد Fe-EDDHA وزن 20 گرم',
#  'کود ورمی کمپوست گیلدا وزن 100 گرم',
#  'کود کامل NPK افزایش رشد گیلدا کد 10-10-30 مدل نیتروژن بالا وزن 25 گرم',
#  'کود تقویتی فروت ست های افکت اریا',
#  'گیاه رازک با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'کود آهن مایع EDTA دوازده درصد پنج لیتری آمریکایی (پس کرایه)',
#  'کود کامل الی گرانوله',
#  'کود کیسه ای ماسل ورم کد MV020 بسته 20 عددی (پس کرایه)',
#  'کود هیومیک اسید',
#  'کود مایع غلیظ فسفر پتاسیم GREEN SOUL پنج لیتری',
#  'کود آهن غلیظ GREEN SOUL پنج لیتری',
#  'کود ویژه برای افزایش محصول+GREEN SOUL Psoul یک کیلوگرمی',
#  'کود عصاره جلبک دریایی سیفر استار وارداتی (پس کرایه)',
#  'کود جیرلکس (جیبرلیک اسید مایع) (پس کرایه)',
#  'کود تقویت کننده سه بیست مکمل غذایی گل ها و گیاهان آپارتمانی',
#  'کود تخصصی ویژه گیاهان زینتی کالاته آ و کروتون',
#  'کود جلبک معروف و نام آشنای یونی گلد(UNI GOLD)',
#  'کود نیتروژن بالا 1-0-40 مناسب رشد رویشی و پهن برگی گیاه مدل hyper Xgreen آمریکایی',
#  'کود ارگانیک گوگرد آلی آلمانی کیوسرت',
#  'کود مایع کلات آهن',
#  'گل طبیعی اشک تمساح متوسط و بزرگ سایز گلدان کد 3',
#  'کود آمینو اسید(اسید آمینه) پودری فلورامی 25 گرمی',
#  'کود سولفات منگنز مدل خانگی وزن 50 گرم',
#  'کود بوریک اسید مدل خانگی وزن 50 گرم',
#  'کود سولفات مس مدل خانگی وزن 50 گرم',
#  'کود کامل NPK سه بیست مدل خانگی وزن 100 گرم',
#  'کود مونو پتاسیم فسفات (34-52-0) مدل خانگی وزن 100 گرم',
#  'کود محرک رشد بمباردیر شوگر مدل خانگی حجم 100 میلی لیتر',
#  'کود عصاره جلبک دریایی مدل خانگی وزن 50 گرم',
#  'کود هیومیک اسید مدل خانگی وزن 100 گرم',
#  'پک کود اقتصادی نگهداری گیاهان آپارتمانی',
#  'کود سه بیست برند پروتکت نیچر',
#  'کود فسفیت پتاسیم کینگ گلد ایکس گرین',
#  'زاموفیلیا  بین 2 تا 4 شاخه ارسال با چاپار تیپاکس پست هزینه با مشتری و پسکرایه',
#  'کود تیوسولفات پتاسیم 5kts لیتری فرمولایف پس کرایه',
#  'آمینو اسید گل و گیاه رویال پلنت 125سی سی فوق العاده عالی',
#  'کود آهن بمب 6 درصد مایع اصل نانو یک لیتری (پس کرایه)',
#  'کود مخصوص رنگ آوری گوجه فرنگی شوک آمریکایی یک لیتری (پس کرایه )',
#  'کود کلسیم بور 34 درصد بمب اصل بیست لیتری (پس کرایه)',
#  'کود ضد سرمازدگی شوک یک لیتری اصل آمریکایی (پس کرایه )',
#  'کود جلبک دریایی مایع پروتکت پلنت 500 میلی لیتر',
#  'کود ارکیده مایع گرین گروث (گلدهی) 90 میلی لیتر',
#  'کود هورمون سیتوکنین مایع پروتکت پلنت 500 میلی لیتر',
#  'کود آهن سولفات (زاج سبز) کریستالون پروتکت پلنت 50 گرم',
#  'کود رکتیفایر جنوبگان pH',
#  'کود مولتی پورپلکس گرومور آمریکا',
#  'کود 105210 ایرانی',
#  'کود اسید هیومیک پلنت چویس',
#  'کود مخصوص بنفشه آفریقایی حجم 30سی سی',
#  'کود فولیار فن فید انگلستان امکس',
#  'کود 105210باواریا آلمان وزن 250گرمی',
#  'کود بنفشه آفریقایی پوکون هلند',
#  'کود مولتی پورپلکس گرمور آمریکا 50سی سی',
#  'کود 105210جنوبگان',
#  'کود سی وید گرومور جلبک دریایی',
#  'کود جلبک دریایی سیویکا جنوبگان',
#  'کود سه بیست 202020باواریا آلمان',
#  'کود روی خالص ارگانیک 100 گرمی ( افزایش سبزینگی و گلدهی و میوه و جوانه زنی)',
#  'کود کلات آهن مناسب گلهای که برگاشون و ساقشون ریز شده تعداد هم موجوده',
#  'کود نیتروزیست (پس کرایه)',
#  'کود میکروژان (پس کرایه)',
#  'کود تقویتی مخصوص گل طاووسی ظرافت وزن 50 گرم',
#  'کود مایع آمینو اسید',
#  'کود ورمی کمپوست صد در صد خالص بستری مناسب برای گیاهان آپارتمانی چالکود درختان باغات و مزارع یک کیلویی(تضمین کیفیت )',
#  'کود کامل هلندی فسفر بالا هورتی گرو 5.50.20 (Hortigrow 5-50-20)',
#  'کود آهن کلات 6درصد اورتو اورتو 3.5 درصد لاین اسپانیا',
#  'کود ریشه زا 19.63 شوک اصل آمریکایی یک لیتری (پس کرایه)',
#  'کود کامل 10X شوک اصل آمریکایی یک لیتری (پس کرایه)',
#  'کود مس23 درصد شوک اصل آمریکایی پنج لیتری (پس کرایه)',
#  'کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (پس کرایه)',
#  'کود مرغی مایع شوک اصل گالن یک لیتری (پس کرایه)',
#  'کود تقویتی مخصوص گل پریوش ظرافت',
#  'کود تقویتی مخصوص یونجه ظرافت',
#  'کود افزایش رشد نیتروژن بالا ( ازت بالا ) NPK 30-10-10 + TE ظرافت مدل KO2767 وزن 50 گرم',
#  'کود تقویتی مخصوص کنگر فرنگی ( آرتیشو ) ظرافت',
#  'کود تقویتی مخصوص دراسینا مارگیناتا ( پرچمی ) ظرافت',
#  'کود تقویتی مخصوص فیکوس ظرافت',
#  'کود تقویتی مخصوص هویا ( پیچ شمعی ) ظرافت',
#  'کود تقویتی مخصوص گل گندمی ظرافت',
#  'کود تقویتی مخصوص فردوس ( سینادنیوم گرانتی ) ظرافت',
#  'کود تقویتی مخصوص خیار ظرافت وزن 50 گرم',
#  'کود مایع گل دهی فلاور آمی 125 میلی لیتر',
#  'کود فسفات آذر سبزینه',
#  'کود تقویتی مخصوص کالاتیا ظرافت',
#  'کود تقویتی مخصوص برگ دهی ظرافت',
#  'کود تقویتی مخصوص گل همیشه بهار ظرافت',
#  'کود تقویتی مخصوص بادرنجبویه ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پیرگیاه ( زلف پیر ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص فیلودندرون قرمز ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص سانسوریا گلد فلیم ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل پامچال ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص درسنا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل طاووسی ظرافت',
#  'کود تقویتی مخصوص فیلودندرون پاندورافورم ظرافت',
#  'کود تقویتی مخصوص شمشاد آپارتمانی ظرافت',
#  'کود تقویتی مخصوص پدیلانتوس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص تاجریزی ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص هویج ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص کلم بروکسل ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل شمعدانی ظرافت',
#  'کود تقویتی مخصوص گل چلچراغ ( عنکبوتی ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص هانی بری ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص اورنج بری ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص درخت فوجیا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل چینی ظرافت',
#  'کود تقویتی مخصوص آشلانتوس پالیده ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص هندوانه ظرافت',
#  'کود تقویتی مخصوص درخت فندق ظرافت',
#  'کود تقویتی مخصوص فیسالیس ( عروسک پشت پرده ) ظرافت',
#  'کود تقویتی مخصوص فروکاکتوس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پتوس ساتین ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پول چینی ظرافت',
#  'کود تقویتی مخصوص گازمانیا ظرافت',
#  'کود تقویتی مخصوص نخل اریکا ( نخل پروانه ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل تاج الملوک ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص فیسالیس ( عروسک پشت پرده ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل سینرر ( سینره ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل گازانیا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص بامبو ظرافت وزن 50 گرم',
#  'کود مایع پاندانوس ( برگ خنجری ) ظرافت حجم 120 میلی لیتر',
#  'کود تقویتی مخصوص پرنده بهشتی ( استرلیتزیا ) ظرافت',
#  'کود تقویتی مخصوص پتوس طلایی ظرافت',
#  'کود تقویتی مخصوص فیلودندرون بورگاندی ظرافت',
#  'کود مارانتا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل حنا ظرافت وزن 50 گرم',
#  'کود مارانتا ظرافت حجم 120 میلی لیتر مدل KO19170',
#  'کود تقویتی مخصوص چمن ظرافت وزن 50 گرم',
#  'کود مایع آهن فلاور آمی 250 میلی لیتر (بسته 3 عددی)',
#  'کود مایع آهن فلاور آمی 125 میلی لیتر',
#  'کود تقویتی مخصوص گل گاوزبان ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص کاکتوس اچینو ظرافت',
#  'کود تقویتی مخصوص استنوتافروم ظرافت',
#  'کود تقویتی مخصوص گل رعنا ظرافت',
#  'کود تقویتی مخصوص درخت هلو ظرافت',
#  'کود تقویتی مخصوص سانسوریا نیزه آفریقایی ( سانسوریا لوله ای ) ظرافت',
#  'کود تقویتی مخصوص سانسوریا کانالیکولاتا ظرافت',
#  'کود تقویتی مخصوص برگ بیدی ظرافت',
#  'کود تقویتی مخصوص درخت بید ظرافت',
#  'کود تقویتی مخصوص انواع نخل آپارتمانی ظرافت',
#  'کود تقویتی مخصوص گل صد تومانی ( پائونیا  پیونی ) ظرافت',
#  'کود تقویتی مخصوص پسودرانتموم ظرافت',
#  'کود تقویتی مخصوص گل ناز فرانسوی ظرافت',
#  'کود تقویتی مخصوص سانسوریا پتنس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص آمارانس ظرافت',
#  'کود تقویتی مخصوص فروکاکتوس ظرافت',
#  'کود تقویتی مخصوص گل چینی ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل لاله عباسی ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل نرگس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص بادرنجبویه ظرافت',
#  'کود تقویتی مخصوص کرفس ظرافت',
#  'کود تقویتی مخصوص کلم بروکسل ظرافت',
#  'کود تقویتی مخصوص لوبیا ظرافت',
#  'کود تقویتی مخصوص فیلودندرون اندریانوم ظرافت',
#  'کود تقویتی مخصوص توت فرنگی ظرافت',
#  'کود افزایش رشد نیتروژن بالا ( ازت بالا ) NPK 30-10-10 + TE ظرافت مدل KO2767 وزن 250 گرم',
#  'کود تقویتی مخصوص لوبیا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص رزماری ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص اونیموس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص ساکولنت فنستریا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل فریزیا ظرافت',
#  'کود تقویتی مخصوص گل درخشنده ( اسکابیوزا ) ظرافت',
#  'کود کامل سیکاس ظرافت مدل KO21340 وزن 250 گرم',
#  'کود مایع نخل ماداگاسکار ظرافت حجم 250 میلی لیتر',
#  'کود کامل تقویتی اشک تمساح ( بریوفیلوم ) ظرافت وزن 250 گرم',
#  'کود نخل مرداب ظرافت مدل KO21349 وزن 100 گرم',
#  'کود کامل تقویتی فیلودندرون الگانس ظرافت وزن 100 گرم مدل KO21421',
#  'کود تقویتی مخصوص نخل شامادورا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پیتسپروم ( میخک ژاپنی  هندی ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پلومریا ظرافت',
#  'کود تقویتی مخصوص گل نماتانتوس ظرافت وزن 50 گرم',
#  'کود هیومیک اسید 90 درصد (بسته 3 عددی)',
#  'کود تقویتی مخصوص درخت زیتون ظرافت وزن 50 گرم',
#  'کود ریز مغذی هربان گروسیف',
#  'کود تقویتی مخصوص کاکتوس اپونتیا میوه دار ( گلابی خاردار ) ظرافت',
#  'کود تقویتی مخصوص ایپومیا ظرافت',
#  'کود تقویتی مخصوص درخت چنار ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل و گیاهان آپارتمانی ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص سیکاس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص کاکتوس مامیلاریا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل حسن یوسف ظرافت',
#  'کود تقویتی مخصوص گل اطلسی ظرافت',
#  'کود تقویتی مخصوص هویا کری ابلق ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پدیلانتوس ظرافت',
#  'کود تقویتی مخصوص درخت سرو ظرافت',
#  'کود تقویتی مخصوص زاموفیلیا ظرافت',
#  'کود آهن مایع اسپانیایی . (60 سی سی )',
#  'کود پتاس بالا مخصوص گلدهی(100گرم )',
#  'کود باغچه پلت یک کیلویی (پس کرایه)',
#  'کود ریشه زایی 10-52-10 حجم 100 گرم',
#  'کود کالمکس گلد (کلسیم و آمینواسید) امکس حجم یک لیتر',
#  'کود کلات روی 15 درصد فلوریش حجم یک کیلوگرم',
#  'کود آپارتمانی آی پلنت بسته دو عددی',
#  'کود 36-12-12 فلوریش حجم یک کیلوگرم',
#  'کود میکرو ریزمغذی فلوریش مدل کمبی حجم یک کیلوگرم',
#  'کود آهن 6 درصد همراه با روی فلوریش حجم یک کیلوگرم',
#  'پک کاکتوس و اشک تمساح',
#  'کود جلبک دریایی',
#  'کود کاج مطبق تایمکس حجم 150 میلی لیتر ( کود مخصوص کاج )',
#  'کود تقویتی مخصوص بنسای با حجم 120 میلی لیتر برند تایمکس',
#  'کود 36 12 12 پتاس',
#  'کود پودر معجزه 400 گرمی گیاهان آپارتمانی',
#  'کود مونو پتاسیم فسفات روکا (پس کرایه)',
#  'کود سولفات پتاسیم 51-0-0 برند کوالی مکس 100 گرمی',
#  'کود جلبک دریایی برند آرمادین کانادایی 100 گرمی',
#  'کود کوآد 14 امکس (Quad 14)',
#  'کود ریشه زایی فسفات بالا دکتر زندی بسته بندی پلاستیک',
#  'کود گلدهی و میوه دهی پتاس بالا صد گرمی دکتر زندی',
#  'کود هیومیک اسید وارداتی میکرولایز',
#  'کود نانو کود فسفر 55 درصد میکرولایز',
#  'کود نانو کود کلات پتاسیم میکرولایز',
#  'کود نانو کود کامل NPK10-52-10+TE میکرولایز',
#  'کود آهنکلات آهنکود آهن پودری',
#  'کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس',
#  'افسنطین با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'کود اوره فسفات',
#  'کود سوپر فسفات ساده',
#  'کود آهن پودری و گرانول',
#  'کود 121236 تحت لیسانس اسپانیا',
#  'کود گیاهان آپارتمانی شوک یک لیتری آمریکایی اصل',
#  'کود گندم و جو شوک یک لیتری آمریکایی اصل',
#  'کود فولویک اسید شوک پنج لیتری آمریکایی اصل',
#  'کود فروت ست شوک بیست لیتری آمریکایی اصل (ارسال رایگان )',
#  'کود گلدهی شوک بیست لیتری',
#  'کود مایع مرغی سان رز (پس کرایه)',
#  'کود سوپر سوئینگ (کلات عناصر ریز مغذی) جنوبگان',
#  'کود عصاره جلبک دریایی موراسپری تتاکو کیلوگرم',
#  'کود محرک رشد فولویک اسید پودری بنیز 50 گرمی',
#  'کود کمپلکس (کامل)نوترازورب مسترگرو',
#  'گیاه خرفه با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'افسنطین با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'ریشه سنبل الطیب با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'برگ مورینگا با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'ریشه کاسنی با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه کاسنی با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گل اسطوخودوس ایرانی بار امسالی و تازه(200گرمی)',
#  'ریشه خولنجان با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه خار مریم با کیفیت عالی بار امسالی و تازه(150 گرمی )',
#  'ریشه شیرین بیان (بدون پوست) بار امسالی و تازه(150گرمی)',
#  'ریشه کاسنی با کیفیت عالی بار امسالی و تازه(50گرمی )',
#  'برگ سنا با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه دم اسب با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'استویا با کیفیت عالی بار امسالی و تازه(750 گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(65گرمی)',
#  'کود آهن مقدار 30گرم پس کرایه',
#  'کود کامل سه بیست npk میلاگرو انقضا 2028',
#  'کود 20 20 20 TE کود سه بیست دارای ریز مغذی(50 گرم ساخت پرتغال)',
#  'کود مخصوص سانسوریا',
#  'کود آهن کلاته راف میلو انقضا 2028',
#  'کود مایع آهن بسته بندی 60 سی سی',
#  'کود مایع آهن برای انواع گلها و باغچه',
#  'کود مایع مرغی 6-6-10 (پس کرایه)',
#  'کود مایع مرغی سوپر ویژه عالی',
#  'گیاه ریش بز (هوم) خشک با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'کود پتاسیم 1236 npk',
#  'کود اوره گرانوله دوکیلویی',
#  'کود 25 گرمی 10-52-10 مخصوص ریشه برند گرومور آمریکا کشور تامین کننده آلمان',
#  'ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(50گرمی )',
#  'ریشه شیرین بیان (بدون پوست) با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'کود شیمیایی سولفات روی',
#  'کود آهن 6 درصد گرومور',
#  'کود افزایش گلدهی و باردهی اکورمون فیوچرکو اسپانیا',
#  'کود تقویت ریشه 10-52-10 وزن 100 گرم دشت سبز',
#  'کود جلبک دریایی سی استار F امکس',
#  'کود هیومیک اسید و فولیک اسید پودری وزن 100 گرم دشت سبز',
#  'کود محرک ریشه بیورادیکانت فیوچرکو اسپانیا حجم یک لیتر',
#  'کود مونو آمینیوم فسفات زنیت',
#  'کود فولویک اسید گیلدا مدل فولوابن وزن 20 گرم',
#  'کود کامل مخصوص بونسای گیلدا وزن 25 گرم',
#  'کود کامل مخصوص NPK سانسوریا گیلدا وزن 25 گرم',
#  'کود هیومیک اسید گیلدا وزن 20 گرم',
#  'کود کامل مخصوص ریشه زایی فسفر 25درصد گیلدا بسته 25 گرمی',
#  'کود فسفر بالا یا 105210 مقدار 30 گرم ارسال بصورت پس کرایه',
#  'کود 202020 مایع',
#  'کود بیوزینک (روی) محصول شرکت نوید نو',
#  'کود 18 18 18 باواریا آلمانی',
#  'کود اسید آمینه هیگروامین برند اکولوژیک تاریم ترکیه (پس کرایه)',
#  'اسپره کود کامل(هزینه ارسال پسکرایه)',
#  'کود NPK 20 20 20 گرواستار',
#  'نهال فوجیا یا فیجوا و یا گواوا آناناسی',
#  'کود 101010 یک کیلویی حاصلخیز با فناوری XGREEN',
#  'کود سبزیجات و صیفی جات 100 میل حاصلخیز با فناوری XGREEN',
#  'کود سیلیکا پرایم Moralpin یک کیلویی',
#  'کود فله ای 105210 npk. زیگلر آلمان .فله ای',
#  'کود فله ای 105210 npk. ..',
#  'کود آهن کلاته 6 درصد فروگان جنوبگان یک کیلویی',
#  'کود فله ای سولوپتاس(سولفات پتاسیم )0.0.52 گما اسپانیا...',
#  'کود میکرو معدنی بهاران (ریز مغذی)نوع B. شش کیلویی',
#  'کود ریزمغذی ریکو اسپانیایی',
#  'کود امینو اسید شوک(پلاس) یک لیتری اصل',
#  'کود ریشه زایی فسفر شوک(پلاس) یک لیتری',
#  'کود پیاز شوک(پلاس) اصلی امریکایی',
#  'کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری',
#  'کود نیتروژن 99درصد شوک(پلاس) یک لیتری مایع',
#  'کود مخصوص گندم شوک(پلاس) امریکایی',
#  'کود کامل گیاهان آپارتمانی',
#  'کود جلبک دریایی 120 سی سی',
#  'کود 12 12 36 (بسته بندی قوطی خانگی)',
#  'برگ مورینگا با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'باباآدم با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'استویا با کیفیت عالی بار امسالی و تازه(500 گرمی)',
#  'گیاه کاسنی با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه خرفه با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه سدر با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'اکالیپتوس با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'برگ جینکو با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه شاهتره با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'آشواگاندا با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'گل بومادارن با کیفیت عالی بار امسالی و تازه(50 گرمی )',
#  'گیاه کاسنی با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'برگ سنا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه رازک با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گل بومادارن با کیفیت عالی بار امسالی و تازه(150 گرمی )',
#  'گیاه خار مریم با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'آلوئه ورا با کیفیت عالی بار امسالی و تازه(250گرمی)',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'ریشه چوبک با کیفیت عالی بار امسالی و تازه(200 گرمی )',
#  'ریشه کاسنی با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'ریشه آنغوزه با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه رازک با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'ریشه خولنجان با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه کاسنی با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'پوست اسفرزه با کیفیت عالی بار امسالی و تازه (200گرمی)',
#  'گل مینا با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گیاه نعناع فلفلی با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'کود اکورمون محرک رشد و گلدهی ضد ریزش گل نیم لیتری',
#  'کود فسفیمکس(فسفیت پتاسیم) 20-30 یک لیتری',
#  'اسپرانتو ادونس- کود کامل همراه ریز مغذی و جلبک',
#  'کودnpk پودری اختصاصی زعفران برند فایواستار بلژیک کیفیت ضمانتی و عالی بسته بندی یک کیلوگرمی',
#  'کود npkپودری 202020 گوما یونان کیسه ده کیلوگرمی کود کامل اصل',
#  'کود فراکتون کیمیتک',
#  'کود تقویتی مخصوص انواع مرکبات هپی پلنت مدل HP445 حجم 120 میلی لیتر',
#  'کود مایع اسید هیومیک و ان پی کا در غلظت مناسب گیاهان خانگی 2 عدد 120 میلی لیتری',
#  'مولتی کود اختصاصی کاکتوس 8 عنصری بسته دو عددی',
#  'مجموعه کود کامل مایع مخصوص گل پتوس مدل گلبان کود سه عددی حجم کل 660 میلی لیتر',
#  'کود کامل مایع مخصوص سانسوریا مدل بهین رشد مجموعه دو عددی حجم کل240 میلی لیتر',
#  'کود مایع NPK20-20-20 بسته دو عددی',
#  'کود مایع اختصاصی گیاه لیندا مدل Danesh Sabz حجم 120 میلی لیتری بسته 8 تایی',
#  'کود مایع اختصاصی آدنیوم مدل Danesh Sabz حجم 120 میلی لیتری بسته 8 تایی',
#  'کود جلبک دریایی شوک(پلاس) امریکایی یک لیتری',
#  'کود تقویتی مخصوص لیندا ظرافت',
#  'کود فول ست ( فروت ست ) مایع بمب 20 لیتری (پسکرایه)',
#  'کود جلبک هیومیک بمب انرژی 2 رویش سبزکود ضدتنش',
#  'سوپر کود ترکیبی انواع گیاهان آپارتمانی. 250 سی سی',
#  'کود آمینو اسید برند پروتکت نیچر',
#  'گیاه دم گیلاس با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'کود کامل سه بیست پلاس 20 20 20 نیکوبذر (گرم بالا)',
#  'گیاه خارشتر با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'کود کامل (نیتروژن فسفر پتاسیم همراه با عناصر )کمپلکس پلاس جنوبگان حجم یک کیلوگرم',
#  'کود بیورادیکانت (کود ریشه زایی) 30 cc',
#  'کود دی پی 98 انگلستان امکس حجم 30سی سی',
#  'کود مخصوص ریشه زایی سانیا کود مدل 10-52-10 وزن 50 گرم',
#  'کود ورمی کمپوست بسته 500 گرمی',
#  'کود کلات آهن . مخصوص گیاهان سبز',
#  'کود فولویک اسید شوک یک لیتری آمریکایی اصل',
#  'کود مایع اختصاصی درسنا کامپکت مدل Danesh Sabz حجم 120 میلی لیتری بسته 8 تایی',
#  'مجموعه کودی پاپیتال وNPK و هیومیک و کود آهن مدل Danesh PK حجم 120 بسته 4تایی',
#  'مجموعه کودی سانسوریا کراواتی وNPK و هیومیک و کود آهن مدل PK حجم 120 بسته 4تایی',
#  'مجموعه سانسوریا کود وNPK و هیومیک و کود آهن مدل Danesh PK حجم 120 بسته 4تایی',
#  'کود مایع مخصوص برگ دهی پتوس بسته سه عددی حجم هر ظرف 100 میلی لیتر',
#  'کود مایع مخصوص شمعدانی بسته سه عددی حجم هر ظرف 100 میلی لیتر',
#  'کود قطره مایع آسان مصرف مخصوص پتوس بسته سه عددی حجم هر ظرف 100 میلی لیتر',
#  'کود کامل و اختصاصی بامبو بسته سه عددی',
#  'کود کامل و اختصاصی آدنیوم بسته سه عددی',
#  'کود کامل و اختصاصی بنت القنسول بسته سه عددی',
#  'کود کامل و اختصاصی گندمی بسته سه عددی',
#  'کود کامل و اختصاصی ریشه زایی پتوس بسته سه عددی',
#  'مولتی کود غنی شده با هیومیک اسید بسته سه عددی',
#  'پک کودی پتوس سه مرحله ای',
#  'مولتی کود اختصاصی بنت القنسول بسته دو عددی',
#  'مولتی کود اختصاصی فیکوس بسته دو عددی',
#  'مولتی کود اختصاصی درسنا بسته دو عددی',
#  'مولتی کود پتوس 8 عنصره بسته سه عددی',
#  'کود مایع کلسیم کود کلسیم ضد ریزش برگ ضد نوک سوزی برگ ضد بد شکلی برگ و میوه',
#  'تجزیه گر کود دامی( جهت پوساندن تک 10 تُنی کود حیوانی)',
#  'کود مایع انرژی سولوشن',
#  'کود کاکتوس پتاس بالا 36-12-6 ایتالیایی گرین گروت-کود کاکتوس-کودGreen Growth-گلدونه',
#  'کود هوس پلنت NPK 18-18-18 - کود ایتالیایی گرین گروت - کود رشد گیاه - تقویتی گیاهان آپارتمانی- کود سانسوریا - گلدونه',
#  'کود کاکتوس و گلدهی پودری 55 گرم- کود پتاس بالا برای گیاهان آپارتمانی- تقویتی گیاهان-کود گلدهی-کود کاکتوس-کود NPK- گلدونه',
#  'کود آمینو اسید - ضد تنش ها و آفات و بیماری ها - تقویتی اسید آمینو - کود گیاهان آپارتمانی - کود گرین گروت - کود گلدونه',
#  'کود کلات مس یک کیلویی شرکت مهر پاسارگاد',
#  'کود هیدرولیز ماهی کماگرو ترکیه',
#  'کود هیومیک اسید شوک آمریکایی 95درصد حجم پنج لیتری',
#  'کود مولتی کمپلکس بزند بمب (ریزمغذی کامل) گالن یک لیتری',
#  'کود فول فروت ست برند بمب مایع گالن پنج لیتری',
#  'کود مایع 20 20 20 دانشمند کوچک مدل اکولایف حجم 120 میلی لیتر',
#  'کود مایع کاکتوس دانشمند کوچک مدل اکولایف حجم 120 میلی لیتر',
#  'روغن ولک گیاه و درختان',
#  'کود آفت کش و ریز مغذی درختان ارگانیک',
#  'کود فسفر بالای زیگلر آلمان 25گرمی 10-52-10',
#  'کود مونوپتاسیم فسفات 34-52-0 زیگلر آلمان 25 گرمی',
#  'کود آمینواسید80درصد  نیترو آمینALGAESTIM برند اگروناترینتز مکزیک25 گرمی',
#  'کود کامل آل مکس جنریت یک لیتری اصلی مناسب تمام گیاهان محصول آمریکا',
#  'کود نانو ازت بالای جنریت ساخت آمریکا (پس کرایه)',
#  'کود چیکوتی (کود مرغی مایع غنی شده)CHICKOTEA(ارسال با باربری یا تیپاکس به صورت پس کرایه)',
#  'کود کاملNpk فسفربالاریشه زا پودری 10-52-10 بسته 150 گرمی مدل نوین کشت',
#  'کود آهن فرمولایف (Fe_EDTA 13%) کلات آهن پودری محلولپاش یک کیلوگرمی',
#  'کود کلات آهن لایفر ایتالیاFeEDDHA6درصد قوطی فلزی یک کیلوگرمی',
#  'کود جنگل ویژه گیاهان آپارتمانی بسته 4عددی',
#  'کود فسفر بالا برند فیروزه',
#  'بنسای جنیسینگ پیوندی هلندی سایز بزرگ بسیار زیبا و با کیفیت',
#  'کود سه بیست مناسب گیاهان آپارتمانی',
#  'فیکوس سبز گیاه آپارتمانی مقاوم و با نگهداری آسان با ارتفاع حدود 50 سانتی متر',
#  'کود گلدهی گیاهان برند فیروزه',
#  'پرنده بهشتی گل سفید بسیار خاص و کمیاب گیاه آپارتمانی با ارتفاع 65 سانتی متر',
#  'گیاه کاج مطبق بلژیکی گیاه آپارتمانی بسیار زیبا و مقاوم با ارتفاع حدود 50 سانت',
#  'کود فروت ست مایعیک لیتریحاوی عناصر ریز مغذی(برای افزایش محصول)',
#  'کود میکروانرژیک اسپانیایی - 750 گرمی (پس کرایه)',
#  'کود مایع آلی حاوی هیومیک اسید GREEN SOUL یک لیتری',
#  'کود مخصوص بونسای سانیا کود مدل 5-9-7 وزن 50 گرم',
#  'اکالیپتوس با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'کود مایع کامل گیاهان آکواریوم آلیتا 500 میلی',
#  'کود مایع جلبک دریایی گیلدا مدل Seaweed حجم 120 میلی لیتر',
#  'کود مایع قلمه زنی و ریشه زایی گیلدا مدل Root Booster حجم 30 میلی لیتر',
#  'پرلیت متوسط دانه اصلی ریشه زایی گل و کنترل رطوبت',
#  'کود هیومیک اسید غنی شده با جلبک دریا گلگیاهان ارجینال',
#  '10.52.10 NPK تی ای پلاس کود ریشه زایی قوی',
#  'کود آهن 100 گرم',
#  'گیاه ترخون خشک پودر شده بار امسالی و تازه(50گرمی )',
#  'گل سر خارگل بار امسالی و تازه(150گرمی)',
#  'گیاه گزنه با کیفیت عالی بار امسالی و تازه(150گرمی )',
#  'گیاه برگ بو پودر شده با کیفیت عالی بار امسالی و تازه(250گرمی)',
#  'ریشه شیرین بیان (بدون پوست) با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'گیاه تره با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'گیاه مورد با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه خار مریم با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گیاه باباآدم بار امسالی و تازه(250 گرمی)',
#  'گیاه نعناع دشتی با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'گیاه تره با کیفیت عالی بار امسالی و تازه(50گرمی )',
#  'گیاه شوید با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه نعناع فلفلی با کیفیت عالی بار امسالی و تازه(150گرمی )',
#  'بولاغ اوتی با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'برگ توت بار امسالی و تازه(50گرمی)',
#  'گیاه مورد با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'گیاه شاهتره با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گیاه نعناع فلفلی بار امسالی و تازه(750گرمی )',
#  'گیاه شوید با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه دم گیلاس پودرشده با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'برگ توت پودرشده بار امسالی و تازه(100گرمی)',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'اکالیپتوس بار امسالی و تازه(100گرمی )',
#  'گیاه شوید با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه مورد با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه گل بنفشه با کیفیت عالی بار امسالی و تازه(50گرم)',
#  'کود مایع ریشه زا بایو رادیکانت',
#  'کود سیلیپات ایدای نیچر اسپانیا',
#  'کود دیسپر کلروفیل جی اس ادن نیم کیلویی',
#  'کود سیلیکات کلسیم یا کلسیل',
#  'گیاه ریش بز (هوم) خشک با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه گل بنفشه پودرشده با کیفیت عالی بار امسالی و تازه(500گرم)',
#  'ریشه کاسنی با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گیاه جعفری با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه کنگر فرنگی پودر شده با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'کود سولفات روی تتاکو مناسب گلدان و باغچه وزن 120 گرم',
#  'کود NPK 10-50-10 تتاکو مناسب گلدان و باغچه وزن 120 گرم',
#  'گیاه کنگر فرنگی با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه مرزنجوش با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گل جنتیانا (گل سپاسی) با کیفیت عالی بار امسالی و تازه(50 گرمی )',
#  'گیاه کنگر فرنگی با کیفیت عالی بار امسالی و تازه(250گرمی)',
#  'گیاه گل بنفشه پودرشده با کیفیت عالی بار امسالی و تازه(250گرم)',
#  'گیاه گل بنفشه با کیفیت عالی بار امسالی و تازه(100گرم)',
#  'گیاه دم گیلاس با کیفیت عالی بار امسالی و تازه(250گرمی)',
#  'گل جنتیانا (گل سپاسی) با کیفیت عالی بار امسالی و تازه(100 گرمی )',
#  'گیاه خار شتر پودر شده بار امسالی و تازه(100گرمی )',
#  'ریشه گزنه با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گیاه خارشتر پودر شده با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'گل مینا با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گیاه سنا هندی با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گل بومادران با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'کود NPK 10 52 10 وُپروفرت دو کیلویی',
#  'کود بیولوژیک پروبیو 96 پودری(نیم کیلویی)',
#  'کود نیتروژن خالص (30 گرمی)',
#  'کود ترکیبی گرانول جلبک و پتاس بالا (700گرمی) (RICO)',
#  'کود گرانول پتاس بالا (55گرمی) (RICO)',
#  'کود آمینون میکرو مافا اسپانیا',
#  'کود بور اتانول آمین مافا اسپانیا',
#  'باکس گل رز جاودان ساقه دار پایه روس همراه گیفت و ساک دستی',
#  'گل رز جاودان قرمز با باکس تمام پلکسی همراه ریسه و ربان',
#  'کود کامل رویال مکس 30-05-15 npk پلنت استار (ارسال به صورت پس کرایه)',
#  'کود مخصوص سانسوریا کود هیومیک اسید برای رشد و پاجوشدهی انواع سانسوریا پک شیش عددی',
#  'کود آمینو اسید ایزابیون سینجنتا یک لیتری',
#  'کود آرامیکس دوکیلویی کیلویی آریا شیمی',
#  'کود فروت ست موبرسین ترکیه',
#  'کود کامل سه بیست 20-20-20 مش بلژیک',
#  'کود کامل ارگانیک ریتاردو اسپانیا',
#  'کود سانسوریا 2عددی',
#  'کود 20 - 20 - 20 ( رشد و تقویت گیاهان )',
#  'کود آهن آگروفا',
#  'کود 20-20-20 سه تایی',
#  'کود آهن (کلات آهن ) 6درصد kollant ایتالیا دوتایی',
#  'کود 36-12-12 سه تایی',
#  'کود کامل رویال مکس 52-00-00 npk پلنت استار (ارسال به صورت پس کرایه )',
#  'کود مایع روتی فرت کود مدل K50 حجم یک لیتر ( پس کرایه )',
#  'کود ریزمغذی دکامیک شاور',
#  'کود میناسول کلسیم (پس کرایه)',
#  'کود ماکرو 121236 (پس کرایه)',
#  'کود اوره فسفات 44 درصد فلوریش (پس کرایه)',
#  'کود 36-12-12 دوتایی',
#  'میکس دوتایی (کود آهن وکود 10-52-10 )',
#  'کود کلسیم یاراویتا-پس کرایه',
#  'کود گلخانه یاراویتا-پس کرایه',
#  'ساکولنت اشک عروس و اشک تمساح',
#  '12.12.36+TE کود تقویتی',
#  'میکس دوتایی (کود آهن و کود 36-12-12 )',
#  'کود کاج مطبق و خانواده سوزنی برگان',
#  'کود کاکتوس تقویتی',
#  'کود هیومیک اسید 95 درصد جنریت آمریکا یک لیتری',
#  'کود مایع مولتی کمپلکس پنج لیتری جنریت محصول آمریکا',
#  'کود فروت ست جنریت (مایع) آمریکایی اصل پنج لیتری',
#  'کود سه بیست مایع جنریت آمریکا پنج لیتری',
#  'کود پتاس بالای K66 جنریت پنج لیتری66درصدپتاس محصول ایالات متحده',
#  'بونسای(شفلرا سبز و ابلق و طلایی)(پس کرایه)',
#  'کود(بیورادیکانت)قوی ترین کود.دکتر یشیل',
#  'کود هیومیک اسید پلنت چویس',
#  'کود تقویتی فیدینگ 10 گرمی لانگ فلوور',
#  'کود محرک ریشه ریژو محصول شرکت کیمیتک',
#  'کود 20-20-20 بلژیکی 100گرمی',
#  'کود پتاس بالا K66 یک لیتری جنریت امریکا غنی شده با اهن و امینواسید',
#  'کود سه بیست دکتر مدل 20-20-20 Dr-NPK وزن 100 گرم',
#  'کود تقویتی مخصوص ریشه دهی و رشد سریع ساقه گلها ارسال با پست و تیپاکس',
#  'دراسینا آناناسی ( کامپکت ) کد 020 ارسال با پست و تیپاکس',
#  'گل آگولنما کالباسی (خارجی) چند بوته ارسال با پست و تیپاکس',
#  'کود هیدروپونیک جامد مخصوص گیاهان آپارتمانی و بونسای کد BO1000',
#  'کود هیدروپونیک جامد مخصوص دوره رویشی کد G1000',
#  'کود هیدروپونیک مایع مخصوص انواع ارکیده کد LO100',
#  'کود هیدروپونیک مایع مخصوص انواع ارکیده کد LOr100',
#  'کود هیدروپونیک مایع مخصوص گل رز و شاخه بریده کد LR100',
#  'کود هیدروپونیک جامد هوگلند کد H1000',
#  'کود هیدروپونیک جامد مخصوص انواع سبزیجات کد V1000',
#  'کود هیدروپونیک جامد مخصوص توت فرنگی کد S100',
#  'کود هیدروپونیک مایع گوجه فرنگی و صیفی جات کد LT1000',
#  'کود سانسوی گرین مدل پودری کد 20 20 20 وزن یک کیلوگرم ( پس کرایه )',
#  'کود کلات روی (EDTA) سانسوی گرین مدل پودری وزن یک کیلوگرم ( پس کرایه)',
#  'کودمرغی چیکود فصل پنجم ارسال با اتوبوس و پس کرایه',
#  'کود مخلوط آهن و پتاسیم سولفات غنی شده',
#  'کود ورمی کمپوست (حداقل خرید از غرفه 400 تومن)(هزینه پسکرایه)',
#  'کود فروت ست خضرا (پس کرایه)',
#  'کود فولویک اسید پودری(فولوی استار) چینی یک کیلویی',
#  'کود آمینو اسید پودری انگبین سبزکاوشان قوطی یک کیلویی',
#  'کود آلی مایع',
#  'کود کلسیمی الی غنی شده با امینواسید یک لیتری',
#  'گیاه خارخاسک با کیفیت عالی بار امسالی و تازه(50 گرمی )',
#  'گل قاصدک با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'بارهنگ با کیفیت عالی بار امسالی و تازه(200 گرمی )',
#  'گل ختمی سفید با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل اسطوخودوس ایرانی بار امسالی و تازه(200گرمی)',
#  'ریشه خولنجان با کیفیت عالی بار امسالی و تازه(200گرمی)',
#  'برگ خرگوشک با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل گاو زبان با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'غنچه گل محمدی با کیفیت عالی بار امسالی و تازه(750گرمی )',
#  'برگ مورینگا با کیفیت عالی بار امسالی و تازه(750گرمی)',
#  'گیاه خارخاسک با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'افتیمون با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'ریشه آنغوزه با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'برگ جینکو با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'استویا با کیفیت عالی بار امسالی و تازه(500 گرمی)',
#  'برگ سنا با کیفیت عالی بار امسالی و تازه(250گرمی )',
#  'گیاه مورد با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'اکالیپتوس با کیفیت عالی بار امسالی و تازه(250 گرمی)',
#  'گل اسطوخودوس (هندی) با کیفیت عالی بار امسالی و تازه(750 گرمی )',
#  'گیاه مریم گلی با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'اکالیپتوس با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه شاهتره با کیفیت عالی بار امسالی و تازه(500گرمی )',
#  'پونه با کیفیت عالی بار امسالی و تازه(150 گرمی )',
#  'آلوئه ورا با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'گل اسطوخودوس (هندی) با کیفیت عالی بار امسالی و تازه(200 گرمی )',
#  'گل بابونه با کیفیت عالی بار امسالی و تازه(100گرمی)',
#  'گیاه خارخاسک با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گل مینا با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'پوست اسفرزه با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گل همیشه بهاربا کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'گیاه مرزه با کیفیت عالی بار امسالی و تازه(50گرمی)',
#  'استویا با کیفیت عالی بار امسالی و تازه(200گرم)',
#  'ریشه آنغوزه با کیفیت عالی بار امسالی و تازه(100گرمی )',
#  'آلوئه ورا با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'گیاه زوفا با کیفیت عالی بار امسالی و تازه(150گرمی)',
#  'فروش ریشه شیرین بیان با کیفیت عالی بار امسالی و تازه(500گرمی)',
#  'بسته شش تایی کود همه کاره ارگانیک ویتامینه گیاهان ویژه ی گیاهان آپارتمانی و زینتی',
#  'بسته هفت تایی کود همه کاره ارگانیک ویتامینه گیاهان ویژه ی گیاهان آپارتمانی و زینتی',
#  'بسته هشت تایی کود همه کاره ارگانیک ویتامینه گیاهان ویژه ی گیاهان آپارتمانی و زینتی',
#  'کود 20-20-20 130 گرمی آگنس',
#  'کود مایع روتی فرت کود مدل NPK 20-20-20 حجم یک لیتر ( پس کرایه )',
#  'کود مخصوص گل حاوی فسفر پتاس ازت(پس کرایه)',
#  'کود مایع فروت ست ویژه جنوبگان مدل پلاس حجم یک لیتر',
#  'کود ریز مغذی منیزیم و گوگرد اریا شیمی مدل آرامیکس وزن 200 گرم',
#  'کود صابون محلول پاشی یونی جنوبگان مدل AB18 حجم 500 میلی لیتر',
#  'کود زیستی بایوران مدل تریکوران پی وزن 500 گرم',
#  'کود پتاسیم منیزیم',
#  'کود کامل ماکرو آسان کود',
#  'کود کلات آهن6درصد متافارم اسپانیا با اورتو-اورتو 5',
#  'کود جلبک دریایی آلگاستیم برند پرینوا مکزیک یک کیلوگرم',
#  'کود سولفات مس پرینوای مکزیک',
#  'کود 36-12-12 NPK خضراء',
#  'کود فسفیت.پتاسیم تحت لیسانس اگروناترینتز دل نورته مکزیک',
#  'کود اسید بوریک گرین پیک مدل BORIC ACID 1000 وزن یک کیلوگرم',
#  'کود کلسیم سوسپانسیون و میکرونیزه آریا شیمی',
#  'کود افزایش سبزینگی و تقویت عمومی گیلدا کد Fe10 وزن 25 گرم',
#  'کود فعال کننده آنزیم های گیاهی گیلدا کد K25-N5 وزن 25 گرم',
#  'کود تقویتی مخصوص گیاهان آپارتمانی NPK 20-20-20',
#  'کود هیدروپونیک جامد مخصوص گوجه فرنگی و صیفی جات کد T1000',
#  'کود ضد تنش و محرک رشد',
#  'اسکاندیس سبز(گلدان کامل و ریشه پر)',
#  'کود تخصصی گیاهان زینتی برگ انجیری و بابا آدم',
#  'کود جلبک دریایی',
#  'کود ویژه برای افزایش محصول+GREEN SOUL Psoul ده کیلوگرمی',
#  'کود آمینو اسید مایع غلیظ GREEN SOUL یک لیتری',
#  'کود مایع غلیظ فروت ست GREEN SOUL پنج لیتری',
#  'کود مایع غلیظ کلسیم ژله ای 5لیتریGREEN SOUL',
#  'فیکوس الاستیکا سایز  دو شاخه قد حدودا 70 80 سانت ارسال با چاپار یا پست انجام میشود و هزینه ی آن با مشتری و پسکرایه',
#  'کود تخصصی ویژه گیاه زینتی دراسنا',
#  'کود تخصصی ویژه گیاهان زینتی بنت قنسول و شفلرا',
#  'کود ارکیده تایمکس حجم 150میلی لیتر مخصوص گل ارکیده',
#  'کود مخصوص گل های آپارتمانی تایمکس حجم 150 میلی لیتر',
#  'کود تقویتی مخصوص گیاه بامبو 150 میلی لیتر برند تایمکس',
#  'کود مایع سه بیست تایمکس ( کود رویشی 20 20 20 ) حجم 150 میلی لیتر',
#  'کود هورمون سیتوکینین تایمکس 150 میلی لیتر برای رشد برگ گل و گیاه',
#  'کود آهن 6 درصد پاکت خانگی',
#  'پک دو تایی گیاه سنسیو و برگ ارغوانی',
#  'کود کلات آهن پرینوا مکزیک',
#  'کود ریشه زایی آلگاروت آنوکا (اسپانیا',
#  'کود کامل جنوبگان نیم لیتر عناصر ماکرو و میکرو',
#  'کود سولفات پتاسیم',
#  'کود ایسی لایف',
#  'کود ستامین فروت ست',
#  'کود سه بیست 202020 بسته 60گرمی',
#  'کود کلات آهن نوتریتال اورتو4/8 الترا اسپانیا',
#  'کود چالکود گرانولی 555 آذین کود',
#  'کود موبرزینک (مولیبدن بر و روی) فلوریش حجم یک کیلوگرم',
#  'کود سولفات پتاسیم (سولوپتاس) زعیم حجم یک کیلوگرم',
#  'کود فرتی روس جنوبگان حجم نیم کیلوگرم(500 گرم)',
#  'میکرو مکس آلفردو اسپانیا (کود ریزمغذی کامل همراه با اسیدآمینه) حجم یک لیتر',
#  'کود مخصوص ریشه زایی',
#  'کود مخصوص سانسوریا و زاموفیلیا',
#  'کود مخصوص گل زاموفیلیا',
#  'کود مایع ازت بالا مخصوص ریشه زایی وتقویت ساقه و برگ',
#  'کود تقویتی مخصوص سانسوریا ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص پیازچه ظرافت',
#  'کود تقویتی مخصوص زرشک ظرافت',
#  'کود تقویتی مخصوص آلوورا ظرافت وزن 50 گرم',
#  'کود فیلودندرون اسکاندیس ظرافت وزن 50 گرم مدل KO19175',
#  'کود تقویتی مخصوص گل آلیسوم ظرافت',
#  'کود تقویتی مخصوص سانسوریا بلک دراگون ( مینیاتوری ) ظرافت',
#  'کود تقویتی مخصوص سانسوریا ماسونی ( باله نهنگی ) ظرافت',
#  'کود تقویتی مخصوص فیلودندرون زانادو ظرافت',
#  'کود تقویتی مخصوص کریپتانتوس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص فیلودندرون زانادو ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص سانسوریا بلک دراگون ( مینیاتوری ) ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص سیر ظرافت وزن 50 گرم',
#  'کود منگزینک پلاس (Mangazinc Plus)',
#  'کود تقویتی مخصوص تره ظرافت',
#  'کود تقویتی مخصوص چغندر ظرافت',
#  'کود تقویتی مخصوص تاج خروس ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل میمون ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص گل سیلین ظرافت وزن 50 گرم',
#  'کود تقویتی مخصوص درخت اکالیپتوس ظرافت وزن 50 گرم',
#  'کود کامل پتاس بالا 30-5-15 زیگلر',
#  'کود فروت ست جامد',
#  'کود کلسیم کلات ایکس گرین یک کیلویی',
#  'کود نیتروژن مایع کالتیفورت اسپانیا',
#  'کود کلات کلسیم پودری ایکس گرین',
#  'کود کلسیم کالمکس الترا امکس',
#  'کود 40-20-10 هاروست ایکس گرین',
#  'کود کاکتوس 125 سی سی پروتکت نیچر',
#  ...]

# %%
df[df["name"].str.contains("سیلیکات", na=False)]
# Out:
#                                                    name category    price  \
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...      NaN   420000
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...      NaN   175000
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...      NaN   480000
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...      NaN   255600
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس      NaN   385000
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری      NaN   400000
# 2620                         کود سیلیکات کلسیم یا کلسیل      NaN   390000
# 2913                            کود سیلیکات پتاسیم زایز      NaN  1175000
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل      NaN   400000
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل      NaN  3700000
# 4081               کود مایعسیلیکات پتاسیم ورساد اسپانیا      NaN   460000
# 4838                        کود سیلیکات پتاسیم اگرولایو      NaN   345000
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...      NaN  1800000
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع ...      NaN   500000
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان      NaN   250000
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک      NaN   580000
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...      NaN  1500000
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر      NaN   735000
# 7780                    سیلیکات پتاسیم سیترال (1 لیتری)      NaN   350000
# 7784                    سیلیکات پتاسیم پروسیل (1 لیتری)      NaN   500000
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان 5 لیتری      NaN  1180000
# 8309                             سیلیکات پتاسیم(5لیتری)      NaN  1200000
#
#       price_per_kg  amount_kg is_available  \
# 1286      420000.0        1.0         True
# 1375      175000.0        1.0         True
# 1385      480000.0        1.0         True
# 1899      255600.0        1.0         True
# 2120      385000.0        1.0         True
# 2304      400000.0        1.0         True
# 2620      390000.0        1.0         True
# 2913     1175000.0        1.0         True
# 3089      400000.0        1.0         True
# 3091       18500.0      200.0         True
# 4081      460000.0        1.0         True
# 4838      345000.0        1.0         True
# 5024      360000.0        5.0         True
# 5032      500000.0        1.0         True
# 5471      250000.0        1.0         True
# 6424      580000.0        1.0         True
# 6511      300000.0        5.0         True
# 7354      147000.0        5.0         True
# 7780      350000.0        1.0         True
# 7784      500000.0        1.0         True
# 8235      236000.0        5.0         True
# 8309      240000.0        5.0         True
#
#                                        product_menu_url  \
# 1286  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1375  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1385  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 1899  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2120  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2304  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2620  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 2913  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 3089  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 3091  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 4081  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 4838  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5024  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5032  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 5471  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 6424  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 6511  https://basalam.com/cat/tools/%D8%AE%D8%A7%DA%...
# 7354                                                NaN
# 7780                                                NaN
# 7784                                                NaN
# 8235                                                NaN
# 8309                                                NaN
#
#                                              name_clean
# 1286  کود سیلیکات پتاسیم ضد ورس گندم ضد سرما و ضد سر...
# 1375  کود مایع روتی فرت کود مدل سیلیکات پتاسیم حجم ی...
# 1385  کود نونامیک سیلیکون (سیلیکات پتاسیم مایع) (پس ...
# 1899  کود سیلیکات پتاسیم شوک اصل آمریکایی یک لیتری (...
# 2120       کود سیلیکات پتاسیم 25 مایع (سیلیکون25) گیگاس
# 2304         کود سیلیکات پتاسیم شوک(پلاس) نانو یک لیتری
# 2620                         کود سیلیکات کلسیم یا کلسیل
# 2913                            کود سیلیکات پتاسیم زایز
# 3089       کود پتاسیم سیلیکات شوک یک لیتری آمریکایی اصل
# 3091     کود پتاسیم سیلیکات شوک بیست لیتری آمریکایی اصل
# 4081               کود مایعسیلیکات پتاسیم ورساد اسپانیا
# 4838                        کود سیلیکات پتاسیم اگرولایو
# 5024  کود سیلیکات پتاسیم مایع اصل آمریکایی شوک (افزا...
# 5032  سیلیکات 70 یک لیتری ایکس گرین ترکیب کودی مایع ...
# 5471             کود سیلیکات پتاسیم (سیلیکاسول) جنوبگان
# 6424       کود جنتاترول سیلیکات پتاسیم تحت لیسانس مکزیک
# 6511  کود پتاسیم سیلیکات شوک پنج لیتری آمریکایی اصل ...
# 7354                کود سیلیکات پتاسیم 2/5 لیتری آگروفر
# 7780                    سیلیکات پتاسیم سیترال (1 لیتری)
# 7784                    سیلیکات پتاسیم پروسیل (1 لیتری)
# 8235             سیلگارد (سیلیکات پتاسیم) ریحان 5 لیتری
# 8309                             سیلیکات پتاسیم(5لیتری)

# %%
import pandas as pd

def contains_all_words(text, words):
    """Check if all words are present in text (any order). Case insensitive."""
    text_lower = str(text).lower()
    return all(word in text_lower for word in words)

for counter, full_name in enumerate(npk_excluded_raw_source.iloc[:, 4].tolist()):
    words = full_name.split()
    
    # Filter rows where 'name' column contains all words (in any order)
    filtered = df[df['name'].apply(lambda x: contains_all_words(x, words))]
    
    if filtered.empty:
        continue  # skip if no matches
    else:
        # Eliminate this row from the dataframe to have unique data
        df = df[~df.isin(filtered)].dropna(how="all")
    
    row = {
        "code": npk_excluded_raw_source.iloc[counter, 2],
        "name": full_name,
        "med": filtered['price_per_kg'].mean(),
        "min": filtered['price_per_kg'].min(),
        "max": filtered['price_per_kg'].max(),
        "std": filtered['price_per_kg'].std(),
        "listOfNames": filtered['name'].tolist(),
        "listOfPrices": filtered['price_per_kg'].tolist(),
    }
    rows.append(row)

result_df = pd.DataFrame(rows)
print(result_df)
# Out:
#       code      name           med           min         max           std  \
# 0   17-111  20 20 20  1.105877e+06  3.250000e+04  29000000.0  3.645248e+06
# 1   17-112  12 12 36  6.393968e+05  2.140000e+05   1600000.0  4.508527e+05
# 2   17-113  10 52 10  1.619690e+06  2.500000e+03  32000000.0  5.517335e+06
# 3   17-115    5 5 15  7.900000e+05  7.900000e+05    790000.0           NaN
# 4   17-116   15 5 30  5.003000e+07  5.003000e+07  50030000.0           NaN
# ..     ...       ...           ...           ...         ...           ...
# 73  19-141       کلر  4.001548e+06  2.450000e+05  15000000.0  5.664002e+06
# 74  11-111      اوره  2.392707e+05  3.400000e+04    900000.0  2.465583e+05
# 75  21-117   کود سبز  7.368454e+05  5.400000e+04   3600000.0  7.602645e+05
# 76  21-115    کمپوست  1.191499e+04  4.882353e+02     25000.0  8.570561e+03
# 77  20-112      مرغی  6.649800e+04  6.800000e+03    270000.0  6.571507e+04
#
#                                           listOfNames  \
# 0   [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 1   [کود 121236npk. زیگلر آلمان. فله ای, کود کامل ...
# 2   [کود کامل 10-52-10 تقویت ریشه دهی و گلدهی, کود...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# ..                                                ...
# 73  [کود دیسپر کلروفیل جی اس ادن نیم کیلویی, کود س...
# 74  [کود اوره گرین پیک مدل UREA 1000 وزن یک کیلوگر...
# 75  [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 76  [کود کمپوست هوشمند ارگانیک ویژه گل های گلدان و...
# 77  [کود مرغی غنی شده گرانول سارک کود, کودمرغی چیک...
#
#                                          listOfPrices
# 0   [1333333.3333333335, 416666.6666666667, 295000...
# 1   [940000.0, 1076923.076923077, 860000.0, 160000...
# 2   [750000.0, 983333.3333333334, 300000.0, 960000...
# 3                                          [790000.0]
# 4                                        [50030000.0]
# ..                                                ...
# 73  [5148000.0, 1242000.0, 1714285.714285714, 1500...
# 74  [139000.0, 100000.0, 590000.0, 100000.0, 45665...
# 75  [1333333.3333333335, 450000.0, 840000.0, 19900...
# 76  [14000.0, 9000.0, 18000.0, 25000.0, 14166.6666...
# 77  [15800.0, 52250.0, 99950.0, 270000.0, 78672.0,...
#
# [78 rows x 8 columns]

# %%
result_df
# Out:
#       code      name           med           min         max           std  \
# 0   17-111  20 20 20  1.105877e+06  3.250000e+04  29000000.0  3.645248e+06
# 1   17-112  12 12 36  6.393968e+05  2.140000e+05   1600000.0  4.508527e+05
# 2   17-113  10 52 10  1.619690e+06  2.500000e+03  32000000.0  5.517335e+06
# 3   17-115    5 5 15  7.900000e+05  7.900000e+05    790000.0           NaN
# 4   17-116   15 5 30  5.003000e+07  5.003000e+07  50030000.0           NaN
# ..     ...       ...           ...           ...         ...           ...
# 73  19-141       کلر  4.001548e+06  2.450000e+05  15000000.0  5.664002e+06
# 74  11-111      اوره  2.392707e+05  3.400000e+04    900000.0  2.465583e+05
# 75  21-117   کود سبز  7.368454e+05  5.400000e+04   3600000.0  7.602645e+05
# 76  21-115    کمپوست  1.191499e+04  4.882353e+02     25000.0  8.570561e+03
# 77  20-112      مرغی  6.649800e+04  6.800000e+03    270000.0  6.571507e+04
#
#                                           listOfNames  \
# 0   [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 1   [کود 121236npk. زیگلر آلمان. فله ای, کود کامل ...
# 2   [کود کامل 10-52-10 تقویت ریشه دهی و گلدهی, کود...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# ..                                                ...
# 73  [کود دیسپر کلروفیل جی اس ادن نیم کیلویی, کود س...
# 74  [کود اوره گرین پیک مدل UREA 1000 وزن یک کیلوگر...
# 75  [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 76  [کود کمپوست هوشمند ارگانیک ویژه گل های گلدان و...
# 77  [کود مرغی غنی شده گرانول سارک کود, کودمرغی چیک...
#
#                                          listOfPrices
# 0   [1333333.3333333335, 416666.6666666667, 295000...
# 1   [940000.0, 1076923.076923077, 860000.0, 160000...
# 2   [750000.0, 983333.3333333334, 300000.0, 960000...
# 3                                          [790000.0]
# 4                                        [50030000.0]
# ..                                                ...
# 73  [5148000.0, 1242000.0, 1714285.714285714, 1500...
# 74  [139000.0, 100000.0, 590000.0, 100000.0, 45665...
# 75  [1333333.3333333335, 450000.0, 840000.0, 19900...
# 76  [14000.0, 9000.0, 18000.0, 25000.0, 14166.6666...
# 77  [15800.0, 52250.0, 99950.0, 270000.0, 78672.0,...
#
# [78 rows x 8 columns]

# %%
# # Others to Dataframe
# for counter in range(len(npk_excluded_raw_source.iloc[:,4].tolist())):
#     name = npk_excluded_raw_source.iloc[:,4].tolist()[counter]
#     filtered = df[df['name'].str.contains(re.escape(name), na=False, case=False)]
#     if filtered.empty:
#         continue  # skip if no matches
    
#     row = {
#         "code": npk_excluded_raw_source.iloc[counter,2], 
#         "name": name,
#         "med": filtered['price_per_kg'].median(), 
#         "min": filtered['price_per_kg'].min(),
#         "max": filtered['price_per_kg'].max(),
#         "std": filtered['price_per_kg'].std(),
#         "listOfNames": filtered['name'].tolist(),
#         "listOfPrices": filtered['price_per_kg'].tolist(),
#     }
#     rows.append(row)

# # Convert list of dicts directly to a DataFrame
# #npkExcludedResultRows = pd.DataFrame(rows)
# result_df = pd.DataFrame(rows)

# print(result_df)

# %%
result_df
# Out:
#       code      name           med           min         max           std  \
# 0   17-111  20 20 20  1.105877e+06  3.250000e+04  29000000.0  3.645248e+06
# 1   17-112  12 12 36  6.393968e+05  2.140000e+05   1600000.0  4.508527e+05
# 2   17-113  10 52 10  1.619690e+06  2.500000e+03  32000000.0  5.517335e+06
# 3   17-115    5 5 15  7.900000e+05  7.900000e+05    790000.0           NaN
# 4   17-116   15 5 30  5.003000e+07  5.003000e+07  50030000.0           NaN
# ..     ...       ...           ...           ...         ...           ...
# 73  19-141       کلر  4.001548e+06  2.450000e+05  15000000.0  5.664002e+06
# 74  11-111      اوره  2.392707e+05  3.400000e+04    900000.0  2.465583e+05
# 75  21-117   کود سبز  7.368454e+05  5.400000e+04   3600000.0  7.602645e+05
# 76  21-115    کمپوست  1.191499e+04  4.882353e+02     25000.0  8.570561e+03
# 77  20-112      مرغی  6.649800e+04  6.800000e+03    270000.0  6.571507e+04
#
#                                           listOfNames  \
# 0   [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 1   [کود 121236npk. زیگلر آلمان. فله ای, کود کامل ...
# 2   [کود کامل 10-52-10 تقویت ریشه دهی و گلدهی, کود...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# ..                                                ...
# 73  [کود دیسپر کلروفیل جی اس ادن نیم کیلویی, کود س...
# 74  [کود اوره گرین پیک مدل UREA 1000 وزن یک کیلوگر...
# 75  [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 76  [کود کمپوست هوشمند ارگانیک ویژه گل های گلدان و...
# 77  [کود مرغی غنی شده گرانول سارک کود, کودمرغی چیک...
#
#                                          listOfPrices
# 0   [1333333.3333333335, 416666.6666666667, 295000...
# 1   [940000.0, 1076923.076923077, 860000.0, 160000...
# 2   [750000.0, 983333.3333333334, 300000.0, 960000...
# 3                                          [790000.0]
# 4                                        [50030000.0]
# ..                                                ...
# 73  [5148000.0, 1242000.0, 1714285.714285714, 1500...
# 74  [139000.0, 100000.0, 590000.0, 100000.0, 45665...
# 75  [1333333.3333333335, 450000.0, 840000.0, 19900...
# 76  [14000.0, 9000.0, 18000.0, 25000.0, 14166.6666...
# 77  [15800.0, 52250.0, 99950.0, 270000.0, 78672.0,...
#
# [78 rows x 8 columns]

# %% [markdown]
# **Correct EXCEPTIONS**

# %%
result_df
# Out:
#       code      name           med           min         max           std  \
# 0   17-111  20 20 20  1.105877e+06  3.250000e+04  29000000.0  3.645248e+06
# 1   17-112  12 12 36  6.393968e+05  2.140000e+05   1600000.0  4.508527e+05
# 2   17-113  10 52 10  1.619690e+06  2.500000e+03  32000000.0  5.517335e+06
# 3   17-115    5 5 15  7.900000e+05  7.900000e+05    790000.0           NaN
# 4   17-116   15 5 30  5.003000e+07  5.003000e+07  50030000.0           NaN
# ..     ...       ...           ...           ...         ...           ...
# 73  19-141       کلر  4.001548e+06  2.450000e+05  15000000.0  5.664002e+06
# 74  11-111      اوره  2.392707e+05  3.400000e+04    900000.0  2.465583e+05
# 75  21-117   کود سبز  7.368454e+05  5.400000e+04   3600000.0  7.602645e+05
# 76  21-115    کمپوست  1.191499e+04  4.882353e+02     25000.0  8.570561e+03
# 77  20-112      مرغی  6.649800e+04  6.800000e+03    270000.0  6.571507e+04
#
#                                           listOfNames  \
# 0   [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 1   [کود 121236npk. زیگلر آلمان. فله ای, کود کامل ...
# 2   [کود کامل 10-52-10 تقویت ریشه دهی و گلدهی, کود...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# ..                                                ...
# 73  [کود دیسپر کلروفیل جی اس ادن نیم کیلویی, کود س...
# 74  [کود اوره گرین پیک مدل UREA 1000 وزن یک کیلوگر...
# 75  [کود کامل پودری 30 گرمی 20-20-20 شرکت زیست فنا...
# 76  [کود کمپوست هوشمند ارگانیک ویژه گل های گلدان و...
# 77  [کود مرغی غنی شده گرانول سارک کود, کودمرغی چیک...
#
#                                          listOfPrices
# 0   [1333333.3333333335, 416666.6666666667, 295000...
# 1   [940000.0, 1076923.076923077, 860000.0, 160000...
# 2   [750000.0, 983333.3333333334, 300000.0, 960000...
# 3                                          [790000.0]
# 4                                        [50030000.0]
# ..                                                ...
# 73  [5148000.0, 1242000.0, 1714285.714285714, 1500...
# 74  [139000.0, 100000.0, 590000.0, 100000.0, 45665...
# 75  [1333333.3333333335, 450000.0, 840000.0, 19900...
# 76  [14000.0, 9000.0, 18000.0, 25000.0, 14166.6666...
# 77  [15800.0, 52250.0, 99950.0, 270000.0, 78672.0,...
#
# [78 rows x 8 columns]

# %%
import pandas as pd
import re

# Irrelevant keywords per fertilizer
irrelevant_map = {
    "اوره": ["سولفات", "فسفات", "گوگرد", "منیزیم", "آهن", "پتاس", "روی", "کلسیم", "گوگردی"],
    "مرغی": ["اوره", "فسفات", "سولفات", "پتاس", "گوگرد", "پلیت", "پلت"],
    "کمپوست": ["اوره", "فسفات", "سولفات", "پتاس", "گوگرد"],
    "کود سبز": ["فسفات", "سولفات", "گوگرد", "نیتروژن", "پتاس", "روی", "کلسیم"],
    "کلر": ["جلبک", "کلروفیل"],
    "کلات مس": ["کلات آهن"],
    "10 52 10": ["فسفات", "فسفر"]
}

def normalize_text(text):
    """Normalize Persian/Arabic text and remove unwanted spaces."""
    text = str(text)
    # Replace Arabic characters with Persian ones
    text = text.replace("ي", "ی").replace("ك", "ک")
    # Remove diacritics
    text = re.sub(r"[\u064B-\u065F]", "", text)
    # Remove zero-width and multiple spaces
    text = re.sub(r"[\u200c\u200f]", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

def filter_irrelevant_for_fertilizer(row):
    fert = normalize_text(row["name"])
    prices = row["listOfPrices"]
    names = [normalize_text(n) for n in row["listOfNames"]]

    irrelevant = irrelevant_map.get(fert, [])
    # Compile regex patterns for speed and accuracy
    patterns = [re.compile(rf"\b{re.escape(bad_kw)}\b", flags=re.IGNORECASE) for bad_kw in irrelevant]

    new_prices, new_names = [], []
    for price, name in zip(prices, names):
        if not any(p.search(name) for p in patterns):
            new_prices.append(price)
            new_names.append(name)

    row["listOfPrices"] = new_prices
    row["listOfNames"] = new_names
    return row

result_df = result_df.apply(filter_irrelevant_for_fertilizer, axis=1)

# %%
import pandas as pd
import re

# Irrelevant keywords per fertilizer
irrelevant_map = {
    "اوره": ["سولفات", "فسفات", "گوگرد", "منیزیم", "آهن", "پتاس", "روی", "کلسیم", "گوگردی"],
    "مرغی": ["اوره", "فسفات", "سولفات", "پتاس", "گوگرد", "پلیت", "پلت"],
    "کمپوست": ["اوره", "فسفات", "سولفات", "پتاس", "گوگرد"],
    "کود سبز": ["فسفات", "سولفات", "گوگرد", "نیتروژن", "پتاس", "روی", "کلسیم"],
    "کلر": ["جلبک", "کلروفیل"],
    "کلات مس": ["کلات آهن"],
    "10 52 10": ["فسفات", "فسفر"]
}

# Map for exact-order splitting
group_order_map = {
    "پتاسیم سیلیکات": r"پتاسیم\s*سیلیکات",
    "سیلیکات پتاسیم": r"سیلیکات\s*پتاسیم"
}

def normalize_text(text):
    """Normalize Persian/Arabic text and remove unwanted spaces."""
    text = str(text)
    text = text.replace("ي", "ی").replace("ك", "ک")
    text = re.sub(r"[\u064B-\u065F]", "", text)  # Remove diacritics
    text = re.sub(r"[\u200c\u200f]", " ", text)   # Remove zero-width chars
    text = re.sub(r"\s+", " ", text).strip()      # Collapse multiple spaces
    return text
def filter_and_split(row):
    fert = normalize_text(row["name"])
    prices = row["listOfPrices"]
    names = [normalize_text(n) for n in row["listOfNames"]]

    # Step 1: Remove irrelevant keywords
    irrelevant = irrelevant_map.get(fert, [])
    patterns = [re.compile(rf"\b{re.escape(bad_kw)}\b", flags=re.IGNORECASE) for bad_kw in irrelevant]
    
    filtered_pairs = [(price, name) for price, name in zip(prices, names)
                      if not any(p.search(name) for p in patterns)]

    # Step 2: Split based on exact order if applicable
    if fert in group_order_map:
        order_pattern = re.compile(group_order_map[fert])
        matching = [(p, n) for p, n in filtered_pairs if order_pattern.search(n)]
    else:
        # If no exact-order pattern, keep everything
        matching = filtered_pairs

    row["listOfPrices"] = [p for p, n in matching]
    row["listOfNames"] = [n for p, n in matching]
    
    return row

# Apply to your DataFrame
result_df = result_df.apply(filter_and_split, axis=1)

# %% [markdown]
# **Remove any Price outlier via IQR**

# %% [markdown]
# write the function for removing outliers by median of the prices

# %%
import statistics
import re
import unicodedata

def normalize_number_string(s: str) -> str:
    """Convert Persian/Arabic digits to English and remove thousands separators."""
    if not isinstance(s, str):
        return s
    # Normalize Unicode
    s = unicodedata.normalize("NFKC", s)
    # Convert Persian digits
    persian_digits = "۰۱۲۳۴۵۶۷۸۹"
    arabic_digits = "٠١٢٣٤٥٦٧٨٩"
    english_digits = "0123456789"
    s = s.translate(str.maketrans(persian_digits, english_digits))
    s = s.translate(str.maketrans(arabic_digits, english_digits))
    # Remove Persian/Arabic/English commas
    s = s.replace("٬", "").replace("،", "").replace(",", "")
    return s

def remove_outliers_iqr(names, prices):
    """
    Removes outliers using the IQR method,
    ensures at least 2 items remain.
    Automatically handles Persian/Arabic digits and sorts by price.
    """
    if not prices:
        return names, prices
    
    # How much robust if smaller become more aggresive
    RATE = 1.5

    # Extract numeric values and sort them by price
    clean_data = []
    for name, price in zip(names, prices):
        if isinstance(price, (int, float)):
            clean_data.append((float(price), name))
        elif isinstance(price, str):
            normalized = normalize_number_string(price)
            match = re.search(r"[-+]?\d*\.?\d+", normalized)
            if match:
                clean_data.append((float(match.group()), name))

    # If fewer than 2 numeric prices, skip filtering
    if len(clean_data) < 2:
        return names, prices

    # Sort by price
    clean_data.sort(key=lambda x: x[0])
    clean_prices = [p for p, _ in clean_data]
    clean_names = [n for _, n in clean_data]

    # Calculate Q1, Q3, and IQR
    q1 = statistics.quantiles(clean_prices, n=4)[0]
    q3 = statistics.quantiles(clean_prices, n=4)[2]
    iqr = q3 - q1
    lower_limit = q1 - RATE * iqr
    upper_limit = q3 + RATE * iqr

    # Filter values within bounds
    filtered_data = [(p, n) for p, n in clean_data if lower_limit <= p <= upper_limit]

    # Ensure at least 2 prices remain
    if len(filtered_data) < 2:
        return names, prices

    # Return sorted filtered results
    filtered_prices = [p for p, _ in filtered_data]
    filtered_names = [n for _, n in filtered_data]
    return filtered_names, filtered_prices

# %%
import math
import statistics

listOfRemovedOutliersByMedian = []

for index, row in result_df.iterrows():
    filtered_outliers_names, filtered_outliers_prices = remove_outliers_iqr(row["listOfNames"], row["listOfPrices"])
    
    # Remove NaN or non-numeric values from prices list
    filtered_outliers_prices = [p for p in filtered_outliers_prices if p is not None and not (isinstance(p, float) and math.isnan(p))]

    if filtered_outliers_prices:
        median = statistics.median(filtered_outliers_prices)
        minimum = min(filtered_outliers_prices)
        maximum = max(filtered_outliers_prices)
        if len(filtered_outliers_prices) >= 2:
            std = statistics.stdev(filtered_outliers_prices)
        else:
            std = None
    else:
        median, minimum, maximum, std = None, None, None, None
    
    listOfRemovedOutliersByMedian.append({
        "code": row['code'],
        "name": row['name'],
        "med": median,
        "min": minimum,
        "max": maximum,
        "std": std,
        "listOfPrices": filtered_outliers_prices,
        "listOfNames": filtered_outliers_names,
    })

dfOfRemovedOutliersByMedian = pd.DataFrame(listOfRemovedOutliersByMedian)
result_df = dfOfRemovedOutliersByMedian
dfOfRemovedOutliersByMedian
# Out:
#       code      name           med           min           max            std  \
# 0   17-111  20 20 20  5.200000e+05  3.250000e+04  1.416667e+06  312472.090560
# 1   17-112  12 12 36  5.532500e+05  2.140000e+05  1.600000e+06  450852.749867
# 2   17-113  10 52 10  3.642708e+05  2.500000e+03  1.000000e+06  278569.457452
# 3   17-115    5 5 15  7.900000e+05  7.900000e+05  7.900000e+05            NaN
# 4   17-116   15 5 30  5.003000e+07  5.003000e+07  5.003000e+07            NaN
# ..     ...       ...           ...           ...           ...            ...
# 73  19-141       کلر  1.242000e+06  6.600000e+05  1.714286e+06  528093.451841
# 74  11-111      اوره  1.150000e+05  4.500000e+04  9.000000e+05  256569.478770
# 75  21-117   کود سبز  4.500000e+05  5.400000e+04  1.333333e+06  355099.359540
# 76  21-115    کمپوست  1.400000e+04  4.882353e+02  2.500000e+04    8570.560847
# 77  20-112      مرغی  6.500000e+04  1.295000e+04  9.995000e+04   29714.337372
#
#                                          listOfPrices  \
# 0   [32500.0, 60000.0, 120000.0, 145000.0, 149000....
# 1   [214000.0, 216720.0, 220000.0, 250000.0, 25000...
# 2   [2500.0, 16095.238095238095, 120000.0, 154800....
# 3                                          [790000.0]
# 4                                        [50030000.0]
# ..                                                ...
# 73           [660000.0, 1242000.0, 1714285.714285714]
# 74  [45000.0, 45665.0, 68000.0, 70000.0, 100000.0,...
# 75  [54000.0, 84500.0, 119750.0, 130000.0, 199000....
# 76  [488.2352941176471, 2750.0, 9000.0, 14000.0, 1...
# 77  [12950.0, 15800.0, 52250.0, 54950.0, 65000.0, ...
#
#                                           listOfNames
# 0   [کود کامل 202020 مایع یک لیتری, کود کامل NPK (...
# 1   [کود سانسوی گرین کد NPK 12-12-36 مدل پودری وزن...
# 2   [کود NPK 10-52-10 وزن 10 کیلوگرم, کود کامل 10-...
# 3                 [کود میکرو ریشه NPK 15-5-15 گروسیف]
# 4                             [کود NPK 15 5 30 زیگلر]
# ..                                                ...
# 73  [اکسی کلرور مس 35 درصد پودر وتابل 1کیلوی, کود ...
# 74  [کود شیمیایی اوره گرانول 46 درصد 1 کیلوگرم, کو...
# 75  [کود اسید انفوریک مایع مگافرتیل ان اس 10 لیتری...
# 76  [کمپوست ملارد (17 کیلوگرم), کمپوست سلولزی کیسه...
# 77  [کود مرغی شوک 20 لیتری, کود مرغی غنی شده گرانو...
#
# [78 rows x 8 columns]

# %% [markdown]
# ***Checking Fertilizers Which Aren't In The List***

# %%
resultList = result_df.iloc[:,1].str.replace("-", " ", regex=False).tolist()
completeList = raw_source_df.iloc[:,4].str.replace("-", " ", regex=False).tolist()
absentFertilizers = [x for x in completeList if x not in resultList]
absentdf = pd.DataFrame({
    "absents": absentFertilizers
})
import datetime
import os

os.makedirs("absents", exist_ok=True)

now_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"absents/fertilizer_absent_{now_str}.xlsx"

absentdf.to_excel(filename, sheet_name="Fertilizer_Absent_Estimations", index=False)

# %%
result_df[result_df["name"]=="سولفات پتاسیم"].listOfNames.tolist()
# Out:
# [['سولفات پتاسیم 50 کیلوگرم',
#   'سولفات پتاسیم 25 کیلوگرم',
#   'کود سولفات پتاسیم جنوبگان وزن 10 کیلوگرم',
#   'سولفات پتاسیم ایرو نیکا 25 کیلوگرمی',
#   'کود سولفات پتاسیم پودری گرین پیک وزن 25 کیلوگرم',
#   'کود سولفات پتاسیم کنجاله ساز 10 کیلو گرمی',
#   'کود سولفات پتاسیم دامافارم 10 کیلویی',
#   'سولفات پتاسیم منیزیم 10/4',
#   'کود سولفات پتاسیم تتاکو ده کیلویی زیگمافرهلند',
#   'کود کاتیوشا(سولفات پتاسیم) جنوبگان(5 لیتری)',
#   'کود سولفات پتاسیم فراگین مدل سولوپتاس وزن 500 گرم',
#   'کود سولفات پتاسیم (سولوپتاس) زعیم حجم یک کیلوگرم',
#   'کود سولفات پتاسیم (سولوپتاس) مهاب کیسه ده کیلویی ساخت ایران',
#   'کود سولفات پتاسیم پودری تایوانی مولتی کم – 25 کیلوگرم',
#   'کود سولفات پتاسیم پودری گرین پیک مدل POTASSIUM SULFATE 1000 وزن یک کیلوگرم',
#   'کود مخلوط آهن و پتاسیم سولفات غنی شده',
#   'کود سولفات پتاسیم 52 کوآلی مکس 10 کیلویی',
#   'کود تقویتی سولفات پتاسیم K+S آلمان پودر 25 کیلوگرم کیسه',
#   'کود فله ای سولوپتاس(سولفات پتاسیم )0.0.52 گما اسپانیا...',
#   'کود سولفات پتاسیم وپروفرت دو کیلویی',
#   'کود فله ای سولوپتاس(سولفات پتاسیم )0.0.52 گما اسپانیا..',
#   'کود سولفات پتاسیم (سولوپتاس) فلوریش پتاسیم 53درصد حجم یک کیلوگرم',
#   'کود سولفات پتاسیم اگریتو 1 کیلویی',
#   'کود سولفات پتاسیم 51-0-0 برند کوالی مکس 100 گرمی',
#   'کود تقویتی سولفات پتاسیم مایع هپی پلنت مدل HP455 حجم 120 میلی لیتر',
#   'کود تیوسولفات پتاسیم 5kts لیتری فرمولایف پس کرایه',
#   'کود کامل مایع زربرگ حاوی عناصر ماکرو و میکرو (ازت سولفات پتاسیم و عناصر کم مصرف مانند آهن روی منگنز منیزیم و ...)',
#   'کود سولفات پتاسیم فلورامی 100 گرمی (potassium Sulfate )',
#   'کود کامل 51-0-0 زیگلر آلمان سولفات پتاسیم 50 گرمی',
#   'کود کامل 51-0-0 زیگلر آلمان سولفات پتاسیم 25 گرمی',
#   'کود سولفات پتاسیم',
#   'کود سولفات پتاسیم 51-0-0 زیگلر آلمان (50 گرم کود خالص)']]

# %% [markdown]
# save the result

# %%
import datetime
import os

os.makedirs("estimation_output", exist_ok=True)

now_str = datetime.datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
filename = f"estimation_output/fertilizer_price_estimations_{now_str}.xlsx"
sheetName = "Fertilizer_Price_Estimations"

with pd.ExcelWriter(filename, engine="xlsxwriter") as writer:
    result_df.to_excel(writer, sheet_name=sheetName, index=False)

    # Get the sheet then freez the first row
    work_sheet = writer.sheets[sheetName]
    work_sheet.freeze_panes(1,0)
