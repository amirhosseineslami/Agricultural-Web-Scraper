# %%
import pandas as pd

df = pd.read_excel("output/price_of_fertilizers - Copy (3).xlsx"
                   ,sheet_name="basalam.com")
df
# Out:
#                                                     url  \
# 0        https://basalam.com/greenrose/product/11745865
# 1     https://basalam.com/arzankadeh7berke/product/1...
# 2     https://basalam.com/goldan.felezi/product/1507...
# 3     https://basalam.com/almase_sorkh/product/11141428
# 4            https://basalam.com/igool/product/16423331
# ...                                                 ...
# 2697     https://basalam.com/baghban051/product/4691011
# 2698     https://basalam.com/baghban051/product/4683724
# 2699     https://basalam.com/baghban051/product/3925658
# 2700  https://basalam.com/dehkadesabz-com/product/24...
# 2701  https://basalam.com/dehkadesabz-com/product/24...
#
#                                                    name  category      price  \
# 0                  خاک و کود آماده کاشت تای سیز 4 لیتری       NaN     45٬000
# 1     خاک و کود بستر مخصوص گیاهان آبزی و میگوها اوشن...       NaN  1٬223٬800
# ...

# %%
# Out:
# 0       1.6
# 1       3.0
# 2       4.0
# 3       2.3
# 4       NaN
#        ...
# 2697    NaN
# 2698    NaN
# 2699    NaN
# 2700    NaN
# 2701    NaN
# Name: amount_kg, Length: 2702, dtype: float64
